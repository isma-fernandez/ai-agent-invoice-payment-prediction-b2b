# %%
from src.data.data_retriever import DataRetriever
from utils.odoo_connector import OdooConnection
import asyncio
import nest_asyncio
from forex_python.converter import CurrencyRates
import pandas as pd
import numpy as np
from datetime import datetime
nest_asyncio.apply()
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
def odoo_missing_values_to_null(df):
    object_cols = df.select_dtypes(include='object').columns
    print(object_cols)
    df[object_cols] = (df[object_cols].replace({False: pd.NA, '' : pd.NA, '/' : pd.NA}))
    df[object_cols] = df[object_cols].applymap(lambda x: np.nan if x == [] else x)
    return df

# %%
def convert_to_datetime(df, columns):
    for col in columns:
        try:
            # formato que no soporta nativamente to_datetime
            if df[col].astype(str).str.contains('/').any():
                df[col] = pd.to_datetime(df[col], errors='coerce', format='%d/%m/%Y')
            else:
                df[col] = pd.to_datetime(df[col], errors='coerce')
        except Exception as e:
            print(f"Error al convertir '{col}': {e}")
    return df

# %%
def check_invalid_date_format(series, date_format='%d/%m/%Y'):
    invalid = []
    for val in series.dropna():
        val = str(val).strip()
        if val == '' or val.lower() == 'false':
            continue
        try:
            datetime.strptime(val, date_format)
        except ValueError:
            invalid.append(val)
    return pd.Series(invalid).drop_duplicates().reset_index(drop=True)

# %% [markdown]
# # Exploración de los datos

# %% [markdown]
# # 1. Estructura de la base de datos

# %% [markdown]
# ## 1.1. Modelos relevantes

# %% [markdown]
# En está sección describo los distintos modelos que deberán ser utilizados.
#
# También he seleccionado los campos que pueden llegar a ser importantes para el desarrollo. Cabe remarcar que con "importantes", no me refiero únicamente para entrenar el modelo de predicción de impagos, también tengo en cuenta información que el agente podría necesitar.

# %% [markdown]
# ### 1.1.1. res.company

# %% [markdown]
# Contiene información sobre las empresas que forman el grupo (no clientes):
# - id
# - name
# - currency_id (Identificador de la moneda [id, nombre])

# %% [markdown]
# ### 1.1.2. res.partner

# %% [markdown]
# Contiene información sobre los partners (clientes/proveedores):
# - id
# - name
# - email
# - phone
# - street
# - city
# - zip
# - country_id
# - customer_rank (>0 es cliente)
# - supplier_rank (>0 es proveedor)
# - category_id (sector/industria a la que pertenece)
# - is_company
# - company_type
# - company_id
# - credit
# - credit_limit
# - debit
# - debit_limit
# - industry_id
# - invoice_ids
# - total_due
# - total_invoiced
# - total_overdue
# - trust
# - unpaid_invoice_ids
# - unpaid_invoices_count

# %% [markdown]
# ### 1.1.3. account.move

# %% [markdown]
# Guarda todas las facturas y movimientos contables de la empresa, es decir, los registros de todo lo que se compra, se vende o se paga. Este será el modelo principal con el que trabajará el agente:
# - id
# - name
# - move_type ("out_invoice", "in_invoice", "out_refund", "in_refund", "entry")
# - payment_state ("not_paid", "in_payment", "paid", "partial", "reversed")
# - company_id
# - partner_id
# - currency_id
# - amount_total
# - amount_paid
# - amount_residual
# - invoice_date
# - invoice_date_due
# - payment_dates
# - date
# - create_date
# - payment_id
# - payment_ids

# %% [markdown]
# ### 1.1.4. res.currency

# %% [markdown]
# Contiene información sobre las monedas en las que se emiten facturas y se registran los movimientos:
# - id
# - name
# - symbol
# - rate

# %% [markdown]
# ### 1.1.5. res.country

# %% [markdown]
# Contiene información sobre los países:
# - id
# - name
# - code

# %% [markdown]
# ### 1.1.6. res.partner.category

# %% [markdown]
# Representa las categorías asignadas a los partners:
# - id
# - name

# %% [markdown]
# ### 1.1.7. res.partner.industry

# %% [markdown]
# Contiene información de la industria / sector económico de los partners:
# - id
# - name

# %% [markdown]
# ## 1.2. Exploración de los datos

# %% [markdown]
# #### Conexión a Odoo

# %%
odoo_connection = OdooConnection()
asyncio.run(odoo_connection.connect())
data_retriever = DataRetriever(odoo_connection=odoo_connection)
# Out:
# Connected to Odoo as albert.gil@yourtechtribe.com (uid: 430)
# Odoo server version: {'server_version': '16.0+e-20250313', 'server_version_info': [16, 0, 0, 'final', 0, 'e'], 'server_serie': '16.0', 'protocol_version': 1}

# %%
#company_df_original = pd.DataFrame(asyncio.run(data_retriever.get_all_companies()))
all_invoices_df_original = pd.DataFrame(asyncio.run(data_retriever.get_all_invoices()))
#partners_df_original = pd.DataFrame(asyncio.run(data_retriever.get_all_customer_partners()))
#currencies_df_original = pd.DataFrame(asyncio.run(data_retriever.get_all_currencies()))
#partner_categories_df_original = pd.DataFrame(asyncio.run(data_retriever.get_all_partner_categories()))
#industrys_df_original = pd.DataFrame(asyncio.run(data_retriever.get_all_industries()))
#invoice_lines_df_original = pd.DataFrame(asyncio.run(data_retriever.get_all_lines_of_all_outbound_invoices()))
# Out:
# Recuperadas 500 facturas, total: 500
# Recuperadas 500 facturas, total: 3000
# Recuperadas 500 facturas, total: 5500
# Recuperadas 500 facturas, total: 8000
# Recuperadas 500 facturas, total: 10500
# Recuperadas 500 facturas, total: 13000
# Recuperadas 500 facturas, total: 15500
# Recuperadas 500 facturas, total: 18000
# Recuperadas 500 facturas, total: 20500
# Recuperadas 500 facturas, total: 23000
# Recuperadas 500 facturas, total: 25500
# Recuperadas 500 facturas, total: 28000
# Recuperadas 500 facturas, total: 30500
# Recuperadas 500 facturas, total: 33000
# Recuperadas 500 facturas, total: 35500
# Recuperadas 500 facturas, total: 38000
# Recuperadas 500 facturas, total: 40500
# Recuperadas 500 facturas, total: 43000
# Recuperadas 500 facturas, total: 45500
# Recuperadas 500 facturas, total: 48000
# Recuperadas 500 facturas, total: 50500
# Recuperadas 500 facturas, total: 53000
# Recuperadas 500 facturas, total: 55500
# Recuperadas 500 facturas, total: 58000
# Recuperadas 500 facturas, total: 60500
# Recuperadas 500 facturas, total: 63000
# Recuperadas 500 facturas, total: 65500
# Recuperadas 500 facturas, total: 68000
# Recuperadas 500 facturas, total: 70500
# Recuperadas 500 facturas, total: 73000
# Recuperadas 500 facturas, total: 75500
# Recuperadas 500 facturas, total: 78000
# Recuperadas 500 facturas, total: 80500
# Recuperadas 500 facturas, total: 83000
# Recuperadas 500 facturas, total: 85500
# Recuperadas 500 facturas, total: 88000
# Recuperadas 500 facturas, total: 90500
# Recuperadas 500 facturas, total: 93000
# Recuperadas 500 facturas, total: 95500
# Recuperadas 500 facturas, total: 98000
# Recuperadas 500 facturas, total: 100500
# Recuperadas 500 facturas, total: 103000
# Recuperadas 500 facturas, total: 105500
# Recuperadas 500 facturas, total: 108000
# Recuperadas 500 facturas, total: 110500
# Recuperadas 500 facturas, total: 113000
# Recuperadas 500 facturas, total: 115500
# Recuperadas 500 facturas, total: 118000
# Recuperadas 500 facturas, total: 120500
# Recuperadas 500 facturas, total: 123000
# Recuperadas 500 facturas, total: 125500
# Recuperadas 500 facturas, total: 128000
# Recuperadas 500 facturas, total: 130500
# Recuperadas 500 facturas, total: 133000
# Recuperadas 500 facturas, total: 135500
# Recuperadas 500 facturas, total: 138000
# Recuperadas 500 facturas, total: 140500
# Recuperadas 500 facturas, total: 143000
# Recuperadas 500 facturas, total: 145500
# Recuperadas 500 facturas, total: 148000
# Recuperadas 500 facturas, total: 150500
# Recuperadas 500 facturas, total: 153000
# Recuperadas 500 facturas, total: 155500
# Recuperadas 500 facturas, total: 158000

# %%
invoice_lines_df_original.to_pickle("invoice_lines.pkl")

# %%
#company_df_original.to_pickle("companies.pkl")
#invoices_df_original.to_pickle("invoices.pkl")
#partners_df_original.to_pickle("partners.pkl")
all_invoices_df_original.to_pickle("all_invoices.pkl")
#currencies_df_original.to_pickle("currencies.pkl")
#partner_categories_df_original.to_pickle("partner_categories.pkl")
#industrys_df_original.to_pickle("industries.pkl")

# %%
invoices_df = pd.read_pickle("invoices.pkl")
company_df = pd.read_pickle("companies.pkl")
partners_df = pd.read_pickle("partners.pkl")
currencies_df = pd.read_pickle("currencies.pkl")
partner_categories_df = pd.read_pickle("partner_categories.pkl")
industries_df = pd.read_pickle("industries.pkl")

# %%
invoices_df = invoices_df_original.copy()
company_df = company_df_original.copy()
partners_df = partners_df_original.copy()
currencies_df = currencies_df_original.copy()
partner_categories_df = partner_categories_df_original.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[123], line 2
#       1 invoices_df = invoices_df_original.copy()
# ----> 2 company_df = company_df_original.copy()
#       3 partners_df = partners_df_original.copy()
#       4 currencies_df = currencies_df_original.copy()
#
# NameError: name 'company_df_original' is not defined

# %%
invoices_df = pd.read_csv
company_df = company_df_original.copy()
partners_df = partners_df_original.copy()
currencies_df = currencies_df_original.copy()
partner_categories_df = partner_categories_df_original.copy()

# %% [markdown]
# ### 1.2.1. res.company

# %%
company_df
# Out:
#     id                                    name currency_id
# 0    1      Grupo Viko Digital Marketing, S.A.    [1, EUR]
# 1    3                       Elogia Media S.L.    [1, EUR]
# 2    2          Ibrands Medios Interactivos SL    [1, EUR]
# 3    5                  Kraz Data Solutions SL    [1, EUR]
# 4    6  Marketing4ecommerce Digital Content SL    [1, EUR]
# 5   13  Octoplus Digital Shelf Optimization SL    [1, EUR]
# 6    7               Tandem Trade Marketing SL    [1, EUR]
# 7   11                    DigitalPla2021, S.L.    [1, EUR]
# 8   14           Ideas y Estrategia Digital SL    [1, EUR]
# 9    8         INICIATIVAS VIRTUALES DE MEXICO   [33, MXN]
# 10  12   IBRANDS MEDIOS INTERACTIVOS DE MEXICO   [33, MXN]
# 11   9             MITTUM MARKETING RELACIONAL   [33, MXN]

# %% [markdown]
# El grupo está formado por 12 empresas, 9 usan el euro y 3 el peso mexicano.

# %% [markdown]
# ### 1.2.2. account.move

# %% [markdown]
# #### Inspección inicial

# %%
invoices_df.head(7000)
# Out:
#           id                       name    move_type payment_state  \
# 0     198507        403-0199881-4444363  out_invoice      not_paid
# 1     198549             FVM/2025/00068  out_invoice      not_paid
# 3     198522             ES501155NOOJRS  out_invoice      not_paid
# 4     198516             ES501152NOOJRS  out_invoice      not_paid
# 6     198471             FVM/2025/00067  out_invoice      not_paid
# ...      ...                        ...          ...           ...
# 7037  174681  INV-FR-476254813-2024-347  out_invoice          paid
# 7038  174697  INV-FR-476254813-2024-346  out_invoice          paid
# 7039  174664   INV-DE-476254813-2024-74  out_invoice          paid
# 7040  174701   INV-DE-476254813-2024-73  out_invoice          paid
# 7041  169355             INT/2024/00001  out_invoice          paid
#
#       company_id partner_id  currency_id  amount_total  amount_residual  \
# 0              7          1            1        43.560           43.560
# 1              6      14913            1       121.000          121.000
# 3              7          1            1       116.160          116.160
# 4              7          1            1        43.560           43.560
# 6              6       8870            1      2420.000         2420.000
# ...          ...        ...          ...           ...              ...
# 7037           7      13924            1        10.200            0.000
# 7038           7      13924            1        10.200            0.000
# 7039           7      13925            1        15.910            0.000
# 7040           7      10892            1        19.820            0.000
# 7041           7         10            1     11495.000            0.000
#
#      invoice_date invoice_date_due payment_dates  \
# 0      2025-11-10       2025-11-06          <NA>
# 1      2025-11-07       2025-12-07          <NA>
# 3      2025-11-06       2025-11-06          <NA>
# 4      2025-11-06       2025-11-06          <NA>
# 6      2025-11-05       2025-11-05          <NA>
# ...           ...              ...           ...
# 7037   2024-12-01       2024-12-16    03/12/2024
# 7038   2024-12-01       2024-12-16    03/12/2024
# 7039   2024-12-01       2024-12-16    03/12/2024
# 7040   2024-12-01       2024-12-16    03/12/2024
# 7041   2024-12-01       2024-12-31    30/12/2024
#
#                                 company_name  \
# 0                  Tandem Trade Marketing SL
# 1     Marketing4ecommerce Digital Content SL
# 3                  Tandem Trade Marketing SL
# 4                  Tandem Trade Marketing SL
# 6     Marketing4ecommerce Digital Content SL
# ...                                      ...
# 7037               Tandem Trade Marketing SL
# 7038               Tandem Trade Marketing SL
# 7039               Tandem Trade Marketing SL
# 7040               Tandem Trade Marketing SL
# 7041               Tandem Trade Marketing SL
#
#                             partner_name currency_name
# 0     Grupo Viko Digital Marketing, S.A.           EUR
# 1                        Ser Sport, S.L.           EUR
# 3     Grupo Viko Digital Marketing, S.A.           EUR
# 4     Grupo Viko Digital Marketing, S.A.           EUR
# 6                         Hero España SA           EUR
# ...                                  ...           ...
# 7037                Marketplaces Francia           EUR
# 7038                Marketplaces Francia           EUR
# 7039               Marketplaces Alemania           EUR
# 7040                 Marketplaces España           EUR
# 7041                   Elogia Media S.L.           EUR
#
# [7000 rows x 15 columns]

# %% [markdown]
# A simple vista se puede apreciar:
# - Se deben convertir los valores '', [] y False (en columnas no booleanas) a NA
# - Facturas sin nombre o con formatos muy diferentes
# - Las últimas facturas aparecen impagadas por ser demasiado recientes
# - Parece que hay algunos campos que no tienen fecha de la factura
# - payment_id y payment_ids parecen no tener nada

# %% [markdown]
# Convierto los valores False / listas vacías a valores NA

# %%
invoices_df = odoo_missing_values_to_null(invoices_df)
# Out:
# Index(['name', 'move_type', 'payment_state', 'company_id', 'partner_id',
#        'currency_id', 'invoice_date', 'invoice_date_due', 'payment_dates',
#        'date', 'create_date', 'payment_ids'],
#       dtype='object')
# C:\Users\Ismae\AppData\Local\Temp\ipykernel_26296\434508603.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[object_cols] = df[object_cols].applymap(lambda x: np.nan if x == [] else x)

# %%
invoices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24288 entries, 0 to 24287
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                24288 non-null  int64
#  1   name              24248 non-null  object
#  2   move_type         24288 non-null  object
#  3   payment_state     24288 non-null  object
#  4   company_id        24288 non-null  object
#  5   partner_id        24280 non-null  object
#  6   currency_id       24288 non-null  object
#  7   amount_total      24288 non-null  float64
#  8   amount_paid       24288 non-null  float64
#  9   amount_residual   24288 non-null  float64
#  10  invoice_date      24276 non-null  object
#  11  invoice_date_due  24288 non-null  object
#  12  payment_dates     19048 non-null  object
#  13  date              24288 non-null  object
#  14  create_date       24288 non-null  object
#  15  payment_id        24288 non-null  bool
#  16  payment_ids       0 non-null      float64
# dtypes: bool(1), float64(4), int64(1), object(11)
# memory usage: 3.0+ MB

# %% [markdown]
# Analizando los valores null:
# - payment_ids es todo null
# - Hay 12 facturas sin fecha, 8 sin información sobre el cliente y 40 sin nombre
# - Varias facturas sin fecha del pago (impagadas o recientes)

# %% [markdown]
# A simple vista, date, create_date, payment_id y payment_ids no son de utilidad, las dos primeras no aportan ninguna información, ya tengo invoice_date, invoice_date_due y payment_dates y las dos últimas son todo False y NA.

# %%
invoices_df = invoices_df.drop(columns=['date', 'create_date', 'payment_id', 'payment_ids'])

# %% [markdown]
# Las listas company_id, partner_id y currency_id, las separaré en dos columnas cada una

# %%
invoices_df['company_name'] = invoices_df['company_id'].apply(lambda x: x[1])
invoices_df['company_id'] = invoices_df['company_id'].apply(lambda x: x[0])

# %%
invoices_df['partner_name'] = invoices_df['partner_id'].apply(lambda x: x[1] if isinstance(x, list) else pd.NA)
invoices_df['partner_id'] = invoices_df['partner_id'].apply(lambda x: x[0] if isinstance(x, list) else pd.NA)
invoices_df['currency_name'] = invoices_df['currency_id'].apply(lambda x: x[1])
invoices_df['currency_id'] = invoices_df['currency_id'].apply(lambda x: x[0])

# %%
invoices_df.head(10000)
# Out:
#           id                           name    move_type payment_state  \
# 0     198507            403-0199881-4444363  out_invoice      not_paid
# 1     198549                 FVM/2025/00068  out_invoice      not_paid
# 2     198548                           <NA>  out_invoice      not_paid
# 3     198522                 ES501155NOOJRS  out_invoice      not_paid
# 4     198516                 ES501152NOOJRS  out_invoice      not_paid
# ...      ...                            ...          ...           ...
# 9995  158574  RECEIPT-IT-476254813-2024-791  out_invoice          paid
# 9996  158560  RECEIPT-IT-476254813-2024-790  out_invoice          paid
# 9997  158563  RECEIPT-IT-476254813-2024-789  out_invoice          paid
# 9998  158570  RECEIPT-IT-476254813-2024-788  out_invoice          paid
# 9999  158577  RECEIPT-IT-476254813-2024-787  out_invoice          paid
#
#       company_id partner_id  currency_id  amount_total  amount_paid  \
# 0              7          1            1        43.560        0.000
# 1              6      14913            1       121.000        0.000
# 2              6      14913            1       726.000        0.000
# 3              7          1            1       116.160        0.000
# 4              7          1            1        43.560        0.000
# ...          ...        ...          ...           ...          ...
# 9995           7      13926            1        11.990        0.000
# 9996           7      13926            1        11.990        0.000
# 9997           7      13926            1        11.990        0.000
# 9998           7      13926            1        11.990        0.000
# 9999           7      13926            1        11.990        0.000
#
#       amount_residual invoice_date invoice_date_due payment_dates  \
# 0              43.560   2025-11-10       2025-11-06          <NA>
# 1             121.000   2025-11-07       2025-12-07          <NA>
# 2             726.000         <NA>       2025-12-07          <NA>
# 3             116.160   2025-11-06       2025-11-06          <NA>
# 4              43.560   2025-11-06       2025-11-06          <NA>
# ...               ...          ...              ...           ...
# 9995            0.000   2024-10-07       2024-10-22    22/10/2024
# 9996            0.000   2024-10-07       2024-10-22    22/10/2024
# 9997            0.000   2024-10-07       2024-10-22    22/10/2024
# 9998            0.000   2024-10-07       2024-10-22    07/10/2024
# 9999            0.000   2024-10-07       2024-10-22    07/10/2024
#
#                                 company_name  \
# 0                  Tandem Trade Marketing SL
# 1     Marketing4ecommerce Digital Content SL
# 2     Marketing4ecommerce Digital Content SL
# 3                  Tandem Trade Marketing SL
# 4                  Tandem Trade Marketing SL
# ...                                      ...
# 9995               Tandem Trade Marketing SL
# 9996               Tandem Trade Marketing SL
# 9997               Tandem Trade Marketing SL
# 9998               Tandem Trade Marketing SL
# 9999               Tandem Trade Marketing SL
#
#                             partner_name currency_name
# 0     Grupo Viko Digital Marketing, S.A.           EUR
# 1                        Ser Sport, S.L.           EUR
# 2                        Ser Sport, S.L.           EUR
# 3     Grupo Viko Digital Marketing, S.A.           EUR
# 4     Grupo Viko Digital Marketing, S.A.           EUR
# ...                                  ...           ...
# 9995                 Marketplaces Italia           EUR
# 9996                 Marketplaces Italia           EUR
# 9997                 Marketplaces Italia           EUR
# 9998                 Marketplaces Italia           EUR
# 9999                 Marketplaces Italia           EUR
#
# [10000 rows x 16 columns]

# %%
invoices_df["id"].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No hay duplicados

# %%
invoices_df.nunique()
# Out:
# id                  24288
# name                23746
# move_type               1
# payment_state           5
# company_id             12
# partner_id           1549
# currency_id             6
# amount_total         6836
# amount_paid             1
# amount_residual       861
# invoice_date          981
# invoice_date_due     1091
# payment_dates         817
# company_name           12
# partner_name         1548
# currency_name           6
# dtype: int64

# %% [markdown]
# Se puede apreciar:
# - Varios nombres de facturas vacíos y duplicados como se ha visto antes
# - Aunque las empresas trabajan con dos monedas internamente, han operado con clientes en 6 monedas diferentes, habrá que hacer las conversiones
# - Parece que amount_paid no tiene ningún valor (0) por tanto, tampoco aporta ninguna información, amount_residual ya tiene lo que falta por pagar, se puede inferir la cantidad pagada
# - Todos los otros campos corresponden a lo esperado

# %% [markdown]
# #### amount_paid

# %%
invoices_df['amount_paid'].mean()
# Out:
# np.float64(0.0)

# %%
invoices_df = invoices_df.drop(columns=['amount_paid'])

# %% [markdown]
# #### name

# %% [markdown]
# Todas las facturas sin nombre no han sido pagadas

# %%
invoices_na_name = invoices_df[invoices_df["name"].isna()]

# %%
invoices_na_name.head()
# Out:
#           id  name    move_type payment_state  company_id partner_id  \
# 2     198548  <NA>  out_invoice      not_paid           6      14913
# 5     198515  <NA>  out_invoice      not_paid           7          1
# 10    198444  <NA>  out_invoice      not_paid           6      15058
# 1134  197217  <NA>  out_invoice      not_paid           7      10892
# 1793  196524  <NA>  out_invoice      not_paid           7      14617
#
#       currency_id  amount_total  amount_residual invoice_date  \
# 2               1       726.000          726.000         <NA>
# 5               1        43.560           43.560   2025-11-06
# 10              1        60.500           60.500         <NA>
# 1134            1         1.000            1.000   2025-07-28
# 1793            1        12.200           12.200         <NA>
#
#      invoice_date_due payment_dates                            company_name  \
# 2          2025-12-07          <NA>  Marketing4ecommerce Digital Content SL
# 5          2025-11-06          <NA>               Tandem Trade Marketing SL
# 10         2025-11-28          <NA>  Marketing4ecommerce Digital Content SL
# 1134       2025-08-12          <NA>               Tandem Trade Marketing SL
# 1793       2025-06-05          <NA>               Tandem Trade Marketing SL
#
#                             partner_name currency_name
# 2                        Ser Sport, S.L.           EUR
# 5     Grupo Viko Digital Marketing, S.A.           EUR
# 10         Banbu Cosmética Natural, S.L.           EUR
# 1134                 Marketplaces España           EUR
# 1793         Marketplaces EMPRESA Italia           EUR

# %%
for col in invoices_na_name.columns:
    print(f"Columna: {col}")
    print(invoices_na_name[col].unique())
# Out:
# Columna: id
# [198548 198515 198444 197217 196524 196523 196186 196144 195208 195203
#  195137 195020 194558 194555 194552 193263 192960 192730 192721 192712
#  192709 192706 192700 192697 192694 192682 192658 192655 192629 192628
#  192623 189566 195202 195200 189531 182747 181419 179523  49220  45100]
# Columna: name
# [<NA>]
# Columna: move_type
# ['out_invoice']
# Columna: payment_state
# ['not_paid']
# Columna: company_id
# [6 7 3 8 1]
# Columna: partner_id
# [14913 1 15058 10892 14617 8571 8996 12056 8870 13043 12537 11041 13567
#  9759 10566 11187 11184 13904 11185 11186 9957 8960 14937 <NA> 8679 12100]
# Columna: currency_id
# [ 1 33  2]
# Columna: amount_total
# [7.2600000e+02 4.3560000e+01 6.0500000e+01 1.0000000e+00 1.2200000e+01
#  1.0000000e+01 0.0000000e+00 4.6400000e+04 4.5820000e+04 1.0035000e+04
#  9.2800000e+03 3.4800000e+03 1.3920000e+05 6.3644966e+05 4.0600000e+04
#  7.0800000e+02 1.4140000e+03 7.6137760e+04 1.2760000e+05 1.1488524e+05
#  9.2624840e+04 9.8901600e+03 2.7980360e+04 7.0794800e+04 1.0440000e+05
#  1.2090831e+05 9.8600000e+04 4.0745000e+04 6.9600000e+04 8.2322400e+03
#  8.1647700e+03 1.3224000e+05 5.3360000e+03]
# Columna: amount_residual
# [7.2600000e+02 4.3560000e+01 6.0500000e+01 1.0000000e+00 1.2200000e+01
#  1.0000000e+01 0.0000000e+00 4.6400000e+04 4.5820000e+04 1.0035000e+04
#  9.2800000e+03 3.4800000e+03 1.3920000e+05 6.3644966e+05 4.0600000e+04
#  7.0800000e+02 1.4140000e+03 7.6137760e+04 1.2760000e+05 1.1488524e+05
#  9.2624840e+04 9.8901600e+03 2.7980360e+04 7.0794800e+04 1.0440000e+05
#  1.2090831e+05 9.8600000e+04 4.0745000e+04 6.9600000e+04 8.2322400e+03
#  8.1647700e+03 1.3224000e+05 5.3360000e+03]
# Columna: invoice_date
# [<NA> '2025-11-06' '2025-07-28' '2025-04-01' '2025-03-26' '2025-03-25'
#  '2025-03-13' '2025-03-11' '2025-03-07' '2025-03-06' '2025-03-03'
#  '2025-03-01' '2025-02-25' '2025-02-06' '2023-07-06' '2023-06-12']
# Columna: invoice_date_due
# ['2025-12-07' '2025-11-06' '2025-11-28' '2025-08-12' '2025-06-05'
#  '2025-05-09' '2025-05-01' '2025-04-10' '2025-03-25' '2025-04-12'
#  '2025-05-12' '2025-04-25' '2025-04-06' '2025-05-15' '2025-05-05'
#  '2025-04-05' '2025-04-02' '2025-03-24' '2025-03-08' '2025-02-03'
#  '2025-01-22' '2023-09-15' '2023-08-15']
# Columna: payment_dates
# [<NA>]
# Columna: company_name
# ['Marketing4ecommerce Digital Content SL' 'Tandem Trade Marketing SL'
#  'Elogia Media S.L.' 'INICIATIVAS VIRTUALES DE MEXICO'
#  'Grupo Viko Digital Marketing, S.A.']
# Columna: partner_name
# ['Ser Sport, S.L.' 'Grupo Viko Digital Marketing, S.A.'
#  'Banbu Cosmética Natural, S.L.' 'Marketplaces España'
#  'Marketplaces EMPRESA Italia' 'Google Ireland Limited'
#  'Aldi Masquefa Supermercados, S.L.U.'
#  'COMERCIALIZADORA ALMACENES GARCIA DE MEXICO' 'Hero España SA'
#  'COMERCIAL HISPANA' 'FRATERNITAS, LLC'
#  'TOYOTA TSUSHO CORPORATION DE MEXICO'
#  'BRITISH AMERICAN TOBACCO SERVICIOS' 'VCD CONSTRUCCION Y DESARROLLO'
#  'BRITISH AMERICAN TOBACCO COLOMBIA SAS' 'LT FASHION' 'RED STRIPES'
#  'BASECO' 'I NOSTRI FRATELLI' 'LEDERY MEXICO' 'BODEGAS LA NEGRITA'
#  'SEPHORA MEXICO' 'PAKKE MEXICO' <NA>
#  'Fira Internacional de Barcelona (ES)' 'DISTRIBUIDORA KROMA']
# Columna: currency_name
# ['EUR' 'MXN' 'USD']

# %% [markdown]
# Parece ser que todas las facturas sin nombre, son pruebas o drafts de facturas que no llegaron a venta, por tanto se pueden eliminar:

# %%
size_na_name = len(invoices_na_name)
count_no_invoice = 0
count_draft_invoice = 0
invoices_no_draft = []
for id in invoices_na_name['id']:
    lines = asyncio.run(data_retriever.get_invoice_line_by_invoice_id(invoice_id=id))
    if len(lines) > 0:
        if 'Draft Invoice' in lines[0]['move_id'][1]:
            count_draft_invoice += 1
        else:
            invoices_no_draft.append(lines)
    else:
        count_no_invoice += 1
print(f"Total invoices with NA name: {size_na_name}")
print(f"Invoices with no invoice lines: {count_no_invoice}")
print(f"Invoices with draft invoice lines: {count_draft_invoice}")
print(f"Invoices with invoice lines but no draft: {len(invoices_no_draft)}")
invoices_no_draft[0]
# Out:
# Total invoices with NA name: 40
# Invoices with no invoice lines: 3
# Invoices with draft invoice lines: 34
# Invoices with invoice lines but no draft: 3
# [{'id': 646426,
#   'move_id': [195203, '(* 195203) (Pruebas)'],
#   'product_id': [46, '[AMAZON DSP (ELOGIA)] AMAZON DSP'],
#   'quantity': 1.0,
#   'price_unit': 0.0,
#   'tax_ids': [102]},
#  {'id': 646427,
#   'move_id': [195203, '(* 195203) (Pruebas)'],
#   'product_id': False,
#   'quantity': 0.0,
#   'price_unit': 0.0,
#   'tax_ids': []}]

# %% [markdown]
# Elimino facturas sin nombre

# %%
invoices_df = invoices_df.dropna(subset=['name'])

# %% [markdown]
# Miro duplicados de nombres

# %%
invoices_df[invoices_df['name'].duplicated()].tail()
# Out:
#           id             name    move_type payment_state  company_id  \
# 24268   9688  INV1/2022/00002  out_invoice          paid           3
# 24272  12146  INV1/2022/00001  out_invoice          paid           7
# 24273  11093  INV1/2022/00001  out_invoice          paid           2
# 24274  10330  INV1/2022/00001  out_invoice          paid           6
# 24275   9687  INV1/2022/00001  out_invoice          paid           3
#
#       partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 24268       8663            1     12195.410            0.000   2022-12-31
# 24272       7454            1      2770.900            0.000   2022-12-31
# 24273       8290            1        30.250            0.000   2022-12-31
# 24274       8619            1      5375.000            0.000   2022-12-31
# 24275       8933            1     17272.330            0.000   2022-12-31
#
#       invoice_date_due payment_dates                            company_name  \
# 24268       2023-02-18    21/02/2023                       Elogia Media S.L.
# 24272       2023-03-10    13/03/2023               Tandem Trade Marketing SL
# 24273       2023-01-15    27/01/2023          Ibrands Medios Interactivos SL
# 24274       2023-02-15    17/03/2023  Marketing4ecommerce Digital Content SL
# 24275       2023-03-15    17/03/2023                       Elogia Media S.L.
#
#                                partner_name currency_name
# 24268                   Irmaos Vila Nova SA           EUR
# 24272    Vent de France La Tramuntana, S.A.           EUR
# 24273  Into The Marketing Media Group, S.L.           EUR
# 24274        Amazon Payments Europe, S.C.A.           EUR
# 24275                        Zambon, S.A.U.           EUR

# %% [markdown]
# Tienen problemas de nombres únicos para facturas entre empresas, 502 facturas con nombres duplicados pero mayoritariamente de diferentes empresas (solo 3 facturas de la misma empresa con el mismo nombre), de momento no afecta demasiado pero está bien saberlo

# %%
print(f"Facturas con nombres iguales: {len(invoices_df[invoices_df['name'].duplicated()])}" )
print(f"Facturas con nombre y company_id iguales: {len(invoices_df[invoices_df.duplicated(subset=['name', 'company_id'])])}")
invoices_df[invoices_df.duplicated(subset=['name', 'company_id'])]
# Out:
# Facturas con nombres iguales: 475
# Facturas con nombre y company_id iguales: 3
#           id           name    move_type payment_state  company_id partner_id  \
# 1166  197173  FACT-2025-XYZ  out_invoice      not_paid           1       <NA>
# 1167  197172  FACT-2025-XYZ  out_invoice      not_paid           1        123
# 1168  197171  FACT-2025-XYZ  out_invoice      not_paid           1        123
#
#       currency_id  amount_total  amount_residual invoice_date  \
# 1166            1         0.000            0.000         <NA>
# 1167            1       484.000          484.000   2025-07-23
# 1168            1       484.000          484.000   2025-07-23
#
#      invoice_date_due payment_dates                        company_name  \
# 1166       2025-07-23          <NA>  Grupo Viko Digital Marketing, S.A.
# 1167       2025-07-23          <NA>  Grupo Viko Digital Marketing, S.A.
# 1168       2025-07-23          <NA>  Grupo Viko Digital Marketing, S.A.
#
#                partner_name currency_name
# 1166                   <NA>           EUR
# 1167  María Sieiro Alfonsin           EUR
# 1168  María Sieiro Alfonsin           EUR

# %%
invoices_df['name'].info()
invoices_df['name'].nunique()
invoices_df['name'].isna().sum()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 23931 entries, 0 to 24287
# Series name: name
# Non-Null Count  Dtype
# --------------  -----
# 23931 non-null  object
# dtypes: object(1)
# memory usage: 373.9+ KB
# np.int64(0)

# %% [markdown]
# #### payment_state

# %%
invoices_df['payment_state'].value_counts()
# Out:
# payment_state
# paid          18931
# not_paid       4839
# reversed        317
# in_payment      141
# partial          20
# Name: count, dtype: int64

# %% [markdown]
# **Facturas revertidas**

# %% [markdown]
# Una factura revertida puede ser por muchos motivos, desde una devolución legítima, una cancelación o un error.

# %%
reversed_invoices = invoices_df[invoices_df['payment_state'] == 'reversed']

# %%
valid_reversed_ids = {}
for id in reversed_invoices['id']:
    reversed_move_id = asyncio.run(odoo_connection.search_read('account.move' , [('id', '=', id)], ['reversal_move_id'], offset=0, limit=0))
    if reversed_move_id and reversed_move_id[0]['reversal_move_id']:
        valid_reversed_ids[id] = reversed_move_id[0]['reversal_move_id'][0]
print(valid_reversed_ids)
# Out:
# {163920: 182474, 166015: 184456, 165692: 185246, 165681: 185244, 165569: 166018, 163760: 177520, 156496: 182458, 167887: 173420, 158252: 184454, 150392: 184332, 149861: 173419, 136528: 182456, 138016: 174183, 136522: 194545, 137970: 173418, 132314: 140543, 120248: 138015, 127142: 194543, 128644: 173417, 129147: 184331, 127978: 136606, 127272: 137783, 128445: 173416, 118437: 138888, 118611: 160300, 118430: 173415, 118237: 136713, 111526: 182448, 118385: 118738, 103604: 112508, 98854: 112506, 102722: 143785, 103388: 136550, 98855: 136326, 98859: 136328, 104476: 109536, 104294: 109534, 82969: 112504, 80681: 161319, 88466: 101264, 88353: 101259, 88288: 100624, 88180: 101255, 87677: 101249, 87672: 101245, 87578: 89245, 87520: 101243, 87244: 100633, 77841: 114825, 77501: 89485, 77840: 89484, 77062: 114823, 77065: 185739, 85759: 100619, 85572: 100621, 84983: 100629, 81595: 92909, 75074: 80694, 75073: 160381, 65705: 109539, 72325: 114821, 67725: 98568, 70611: 120118, 70323: 80693, 81042: 100617, 66003: 75072, 65999: 114819, 61821: 75831, 65522: 65899, 64003: 65696, 56698: 100331, 61210: 70609, 61212: 114817, 56796: 75830, 53111: 75829, 55459: 98567, 55458: 98517, 56701: 114815, 51449: 102476, 48765: 114813, 45377: 89483, 53840: 63153, 53468: 63149, 53423: 63142, 42981: 89448, 41111: 185737, 38945: 114811, 28362: 29996, 28201: 29847, 28178: 29848, 24203: 114809, 25958: 28174, 23191: 23763, 17375: 64750, 17376: 70305, 17506: 62290, 17399: 70488, 21036: 21579, 17668: 21584, 17171: 19844, 9383: 70120, 13237: 75810, 11264: 62463, 11261: 62465, 11380: 19986, 11172: 80054, 13120: 65704, 9696: 18701, 11097: 104002, 13244: 158190, 13079: 69149}

# %% [markdown]
# Las facturas que tienen otra factura asociada con la revertida son todas devoluciones, las que no tienen no hay forma de saber exactamente el motivo, por tanto, dada la baja concentración de estas en todo el dataset, simplemente eliminaré las filas

# %%
reversal_invoices = []
reversal_invoices_move_type = []
for reversed_id, original_id in valid_reversed_ids.items():
    reversal_invoices.append(asyncio.run(data_retriever.get_invoice_by_id(invoice_id=original_id)))
    reversal_invoices_move_type.append(reversal_invoices[-1]['move_type'])
print(reversal_invoices_move_type)
# Out:
# ['out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund', 'out_refund']

# %% [markdown]
# Elimino las facturas revertidas

# %%
invoices_df = invoices_df[~invoices_df['id'].isin(reversed_invoices['id'])]

# %%
invoices_df['payment_state'].value_counts()
# Out:
# payment_state
# paid          18931
# not_paid       4879
# in_payment      141
# partial          20
# Name: count, dtype: int64

# %%
invoices_df
# Out:
#            id                 name    move_type payment_state  company_id  \
# 0      198507  403-0199881-4444363  out_invoice      not_paid           7
# 1      198549       FVM/2025/00068  out_invoice      not_paid           6
# 3      198522       ES501155NOOJRS  out_invoice      not_paid           7
# 4      198516       ES501152NOOJRS  out_invoice      not_paid           7
# 6      198471       FVM/2025/00067  out_invoice      not_paid           6
# ...       ...                  ...          ...           ...         ...
# 24283    1043       FVK/2022/00005  out_invoice          paid           5
# 24284    1042       FVK/2022/00004  out_invoice          paid           5
# 24285    1041       FVK/2022/00003  out_invoice          paid           5
# 24286    1040       FVK/2022/00002  out_invoice          paid           5
# 24287    1044       FVK/2022/00001  out_invoice          paid           5
#
#       partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 0              1            1        43.560           43.560   2025-11-10
# 1          14913            1       121.000          121.000   2025-11-07
# 3              1            1       116.160          116.160   2025-11-06
# 4              1            1        43.560           43.560   2025-11-06
# 6           8870            1      2420.000         2420.000   2025-11-05
# ...          ...          ...           ...              ...          ...
# 24283       7812            1       242.000            0.000   2022-10-31
# 24284       7485            1      9075.000            0.000   2022-10-31
# 24285       7773            1      5808.000            0.000   2022-10-31
# 24286       7409            1      4961.000            0.000   2022-10-31
# 24287       7812            1       847.000            0.000   2022-09-30
#
#       invoice_date_due payment_dates                            company_name  \
# 0           2025-11-06          <NA>               Tandem Trade Marketing SL
# 1           2025-12-07          <NA>  Marketing4ecommerce Digital Content SL
# 3           2025-11-06          <NA>               Tandem Trade Marketing SL
# 4           2025-11-06          <NA>               Tandem Trade Marketing SL
# 6           2025-11-05          <NA>  Marketing4ecommerce Digital Content SL
# ...                ...           ...                                     ...
# 24283       2023-02-20    23/02/2023                  Kraz Data Solutions SL
# 24284       2023-01-02    06/01/2023                  Kraz Data Solutions SL
# 24285       2022-12-30    02/01/2023                  Kraz Data Solutions SL
# 24286       2023-01-25    30/01/2023                  Kraz Data Solutions SL
# 24287       2023-01-14    24/01/2023                  Kraz Data Solutions SL
#
#                              partner_name currency_name
# 0      Grupo Viko Digital Marketing, S.A.           EUR
# 1                         Ser Sport, S.L.           EUR
# 3      Grupo Viko Digital Marketing, S.A.           EUR
# 4      Grupo Viko Digital Marketing, S.A.           EUR
# 6                          Hero España SA           EUR
# ...                                   ...           ...
# 24283           Salvetti & Llombart, S.L.           EUR
# 24284               Unilever España, S.A.           EUR
# 24285                      Kave Home S.L.           EUR
# 24286          Ferrer Internacional, S.A.           EUR
# 24287           Salvetti & Llombart, S.L.           EUR
#
# [23931 rows x 15 columns]

# %% [markdown]
# **Facturas en proceso de pago**

# %% [markdown]
# Parece que todas las facturas en proceso de pago no tienen cantidades por pagar en amount_residual a diferencia de las facturas no pagas o parcialmente pagadas. Eso significa normalmente que no están conciliadas, pero como account.payment únicamente tiene pagos salientes de las empresas y no entrantes de los clientes, no puedo comprobarlo.

# %%
invoices_in_payment = invoices_df[invoices_df['payment_state'] == 'in_payment']
invoices_in_payment.head()
# Out:
#           id            name    move_type payment_state  company_id  \
# 3426  183800  MIR/2025/00185  out_invoice    in_payment           7
# 3427  183799  MIR/2025/00184  out_invoice    in_payment           7
# 3428  183798  MIR/2025/00183  out_invoice    in_payment           7
# 3429  183797  MIR/2025/00182  out_invoice    in_payment           7
# 3430  183796  MIR/2025/00181  out_invoice    in_payment           7
#
#      partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 3426      10892            1        23.900            0.000   2025-01-30
# 3427      10892            1        19.900            0.000   2025-01-30
# 3428      10892            1        26.980            0.000   2025-01-30
# 3429      10892            1        26.980            0.000   2025-01-30
# 3430      10892            1        26.980            0.000   2025-01-30
#
#      invoice_date_due payment_dates               company_name  \
# 3426       2025-02-14    03/02/2025  Tandem Trade Marketing SL
# 3427       2025-02-14    03/02/2025  Tandem Trade Marketing SL
# 3428       2025-02-14    03/02/2025  Tandem Trade Marketing SL
# 3429       2025-02-14    03/02/2025  Tandem Trade Marketing SL
# 3430       2025-02-14    03/02/2025  Tandem Trade Marketing SL
#
#              partner_name currency_name
# 3426  Marketplaces España           EUR
# 3427  Marketplaces España           EUR
# 3428  Marketplaces España           EUR
# 3429  Marketplaces España           EUR
# 3430  Marketplaces España           EUR

# %%
invoices_with_residual = invoices_df[invoices_df['amount_residual'] > 0]
invoices_with_residual_in_payment = invoices_in_payment[invoices_in_payment['amount_residual'] > 0]
print(f"Facturas en proceso de pago con amount_residual > 0: {len(invoices_with_residual_in_payment)}")
print(f"Facturas con amount_residual > 0: {len(invoices_with_residual)}")
invoices_with_residual.head()
# Out:
# Facturas en proceso de pago con amount_residual > 0: 0
# Facturas con amount_residual > 0: 4855
#        id                 name    move_type payment_state  company_id  \
# 0  198507  403-0199881-4444363  out_invoice      not_paid           7
# 1  198549       FVM/2025/00068  out_invoice      not_paid           6
# 3  198522       ES501155NOOJRS  out_invoice      not_paid           7
# 4  198516       ES501152NOOJRS  out_invoice      not_paid           7
# 6  198471       FVM/2025/00067  out_invoice      not_paid           6
#
#   partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 0          1            1        43.560           43.560   2025-11-10
# 1      14913            1       121.000          121.000   2025-11-07
# 3          1            1       116.160          116.160   2025-11-06
# 4          1            1        43.560           43.560   2025-11-06
# 6       8870            1      2420.000         2420.000   2025-11-05
#
#   invoice_date_due payment_dates                            company_name  \
# 0       2025-11-06          <NA>               Tandem Trade Marketing SL
# 1       2025-12-07          <NA>  Marketing4ecommerce Digital Content SL
# 3       2025-11-06          <NA>               Tandem Trade Marketing SL
# 4       2025-11-06          <NA>               Tandem Trade Marketing SL
# 6       2025-11-05          <NA>  Marketing4ecommerce Digital Content SL
#
#                          partner_name currency_name
# 0  Grupo Viko Digital Marketing, S.A.           EUR
# 1                     Ser Sport, S.L.           EUR
# 3  Grupo Viko Digital Marketing, S.A.           EUR
# 4  Grupo Viko Digital Marketing, S.A.           EUR
# 6                      Hero España SA           EUR

# %%
invoices_df.to_pickle("invoices_cleanedv1.pkl")

# %%
invoices_df = pd.read_pickle("invoices_cleanedv1.pkl")

# %% [markdown]
# Voy a ver si en account.move.line puedo encontrar más información.

# %%
invoice_lines = []
for id in invoices_in_payment['id']:
    lines = asyncio.run(data_retriever.get_invoice_line_by_invoice_id(invoice_id=id))
    invoice_lines.append(lines)

# %%
flat_list = [item for sublist in invoice_lines for item in sublist]
invoice_lines_in_payment = pd.DataFrame(flat_list)

# %%
invoices_lines_in_payment
# Out:
#          id                                   move_id  \
# 0    610843  [183800, MIR/2025/00185 (7004977564677)]
# 1    610844  [183800, MIR/2025/00185 (7004977564677)]
# 2    610845  [183800, MIR/2025/00185 (7004977564677)]
# 3    610840  [183799, MIR/2025/00184 (6921669964677)]
# 4    610841  [183799, MIR/2025/00184 (6921669964677)]
# ..      ...                                       ...
# 487   35852                   [16908, FVE/2023/00026]
# 488   35853                   [16908, FVE/2023/00026]
# 489   35854                   [16908, FVE/2023/00026]
# 490   35855                   [16908, FVE/2023/00026]
# 491   35856                   [16908, FVE/2023/00026]
#
#                                             product_id  quantity  price_unit  \
# 0    [240, [752460] JW Red          1L        06X01...     1.000      19.750
# 1                                                 <NA>     0.000       0.000
# 2                                                 <NA>     0.000       0.000
# 3    [241, [752394] JW Red          70cl      06X01...     1.000      16.450
# 4                                                 <NA>     0.000       0.000
# ..                                                 ...       ...         ...
# 487                         [12, [UX (ELOGIA CRO)] UX]     1.000    1000.000
# 488                       [14, [SEO (ELOGIA CRO)] SEO]     1.000     600.000
# 489         [11, [FEES PAID (ELOGIA)] FEES PAID MEDIA]     1.000     500.000
# 490                                               <NA>     0.000       0.000
# 491                                               <NA>     0.000       0.000
#
#     tax_ids  reconciled  blocked date_maturity    debit   credit   balance  \
# 0     [701]       False    False          <NA>    0.000   19.750   -19.750
# 1       NaN       False    False          <NA>    0.000    4.150    -4.150
# 2       NaN        True    False    2025-02-14   23.900    0.000    23.900
# 3     [701]       False    False          <NA>    0.000   16.450   -16.450
# 4       NaN       False    False          <NA>    0.000    3.450    -3.450
# ..      ...         ...      ...           ...      ...      ...       ...
# 487   [302]       False    False          <NA>    0.000 1000.000 -1000.000
# 488   [302]       False    False          <NA>    0.000  600.000  -600.000
# 489   [302]       False    False          <NA>    0.000  500.000  -500.000
# 490     NaN       False    False          <NA>    0.000  924.000  -924.000
# 491     NaN        True    False    2023-04-01 5324.000    0.000  5324.000
#
#      amount_residual currency_id                      company_id  discount  \
# 0              0.000    [1, EUR]  [7, Tandem Trade Marketing SL]     0.000
# 1              0.000    [1, EUR]  [7, Tandem Trade Marketing SL]     0.000
# 2              0.000    [1, EUR]  [7, Tandem Trade Marketing SL]     0.000
# 3              0.000    [1, EUR]  [7, Tandem Trade Marketing SL]     0.000
# 4              0.000    [1, EUR]  [7, Tandem Trade Marketing SL]     0.000
# ..               ...         ...                             ...       ...
# 487            0.000    [1, EUR]          [3, Elogia Media S.L.]     0.000
# 488            0.000    [1, EUR]          [3, Elogia Media S.L.]     0.000
# 489            0.000    [1, EUR]          [3, Elogia Media S.L.]     0.000
# 490            0.000    [1, EUR]          [3, Elogia Media S.L.]     0.000
# 491            0.000    [1, EUR]          [3, Elogia Media S.L.]     0.000
#
#      discount_percentage full_reconcile_id  is_downpayment  reconcile_model_id
# 0                  0.000              <NA>           False               False
# 1                  0.000              <NA>           False               False
# 2                  0.000   [57259, A57259]           False               False
# 3                  0.000              <NA>           False               False
# 4                  0.000              <NA>           False               False
# ..                   ...               ...             ...                 ...
# 487                0.000              <NA>           False               False
# 488                0.000              <NA>           False               False
# 489                0.000              <NA>           False               False
# 490                0.000              <NA>           False               False
# 491                0.000   [49471, A49471]           False               False
#
# [492 rows x 20 columns]

# %% [markdown]
# Parece ser que todas las facturas tienen lineas asociadas

# %%
invoices_lines_in_payment = odoo_missing_values_to_null(invoice_lines_in_payment)
invoices_lines_in_payment.info()
# Out:
# Index(['move_id', 'product_id', 'tax_ids', 'date_maturity', 'currency_id',
#        'company_id', 'full_reconcile_id'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   492 non-null    int64
#  1   move_id              492 non-null    object
#  2   product_id           210 non-null    object
#  3   quantity             492 non-null    float64
#  4   price_unit           492 non-null    float64
#  5   tax_ids              210 non-null    object
#  6   reconciled           492 non-null    bool
#  7   blocked              492 non-null    bool
#  8   date_maturity        141 non-null    object
#  9   debit                492 non-null    float64
#  10  credit               492 non-null    float64
#  11  balance              492 non-null    float64
#  12  amount_residual      492 non-null    float64
#  13  currency_id          492 non-null    object
#  14  company_id           492 non-null    object
#  15  discount             492 non-null    float64
#  16  discount_percentage  492 non-null    float64
#  17  full_reconcile_id    142 non-null    object
#  18  is_downpayment       492 non-null    bool
#  19  reconcile_model_id   492 non-null    bool
# dtypes: bool(4), float64(8), int64(1), object(7)
# memory usage: 63.6+ KB
# C:\Users\Ismae\AppData\Local\Temp\ipykernel_29760\434508603.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[object_cols] = df[object_cols].applymap(lambda x: np.nan if x == [] else x)

# %%
invoices_lines_in_payment['move_id'] = invoices_lines_in_payment['move_id'].apply(lambda x: x[0] if isinstance(x, list) else pd.NA)

# %%
invoices_lines_in_payment['move_id'].nunique()
# Out:
# 141

# %% [markdown]
# Aunque las facturas aparecen en proceso de pago, en las lineas de la factura aparecen reconciliadas, voy a comparar con una factura no pagada

# %%
invoices_lines_in_payment['reconciled'].value_counts()
# Out:
# reconciled
# False    350
# True     142
# Name: count, dtype: int64

# %% [markdown]
# En el caso de la factura impagada, no aparece reconciliada, por tanto asumo que es un error y algunas facturas en proceso de pago si que estan pagadas

# %%
lines_invoice_not_paid = asyncio.run(data_retriever.get_invoice_line_by_invoice_id(198522))
pd.DataFrame(lines_invoice_not_paid)['reconciled']
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: reconciled, dtype: bool

# %% [markdown]
# En las facturas pagadas si que aparece y coincide con el balance el total de la factura

# %%
lines_invoice_paid = asyncio.run(data_retriever.get_invoice_line_by_invoice_id(174681))
print("Reconciled: ", lines_invoice_paid[2]['reconciled'])
print("Total amount paid:", invoices_df[invoices_df['id'] == 174681]['amount_total'].values[0])
print("Total balance line: ", lines_invoice_paid[2]['balance'])
pd.DataFrame(lines_invoice_paid)['reconciled']
lines_invoice_paid[2]['balance'] == invoices_df[invoices_df['id'] == 174681]['amount_total']
# Out:
# Reconciled:  True
# Total amount paid: 10.2
# Total balance line:  10.2
# 7037    True
# Name: amount_total, dtype: bool

# %% [markdown]
# Compruebo que no tengan cantidades restantes por pagar y no es el caso

# %%
invoices_lines_in_payment['amount_residual'].mean()
# Out:
# np.float64(0.0)

# %% [markdown]
# Comprobando que todas las facturas en proceso de pago tengan el mismo balance que el monto total, se puede ver que todas menos una estan pagadas al 100%

# %%
invoices_lines_in_payment_reconciled = invoices_lines_in_payment[invoices_lines_in_payment['reconciled'] == True]
reconciled_in_payment = 0
not_paid = []
for move_id in invoices_lines_in_payment_reconciled['move_id']:
    related_invoice = invoices_in_payment[invoices_in_payment['id'] == move_id]
    if related_invoice['amount_total'].values[0] == invoices_lines_in_payment_reconciled[invoices_lines_in_payment_reconciled['move_id'] == move_id]['balance'].values[0]:
        reconciled_in_payment += 1
    else:
        not_paid.append(move_id)
print("Reconciled and fully paid invoices in 'in_payment' state:", reconciled_in_payment)
# Out:
# Reconciled and fully paid invoices in 'in_payment' state: 140

# %% [markdown]
# Parece un error simplemente, -1680 + 268,8 = 1948,8, y amount_residual = 0, por tanto también está pagada

# %%
invoice_lines_in_payment[invoice_lines_in_payment['move_id'] == 153724]
# Out:
#          id  move_id                          product_id  quantity  \
# 475  510856   153724  [22, [CSP (IBRANDS)] CONSUPERMISO]    42.000
# 476  510857   153724                                <NA>     0.000
# 477  510858   153724                                <NA>     0.000
#
#      price_unit tax_ids  reconciled  blocked date_maturity    debit   credit  \
# 475      40.000  [1002]       False    False          <NA>    0.000 1680.000
# 476       0.000     NaN        True    False          <NA>    0.000  268.800
# 477       0.000     NaN        True    False    2024-11-21 1948.800    0.000
#
#       balance  amount_residual currency_id  \
# 475 -1680.000            0.000   [33, MXN]
# 476  -268.800            0.000   [33, MXN]
# 477  1948.800            0.000   [33, MXN]
#
#                                       company_id  discount  \
# 475  [12, IBRANDS MEDIOS INTERACTIVOS DE MEXICO]     0.000
# 476  [12, IBRANDS MEDIOS INTERACTIVOS DE MEXICO]     0.000
# 477  [12, IBRANDS MEDIOS INTERACTIVOS DE MEXICO]     0.000
#
#      discount_percentage full_reconcile_id  is_downpayment  reconcile_model_id
# 475                0.000              <NA>           False               False
# 476                0.000   [50388, A50388]           False               False
# 477                0.000   [50389, A50389]           False               False

# %%
invoices_df[invoices_df['id'] == 153724]
# Out:
#           id          name    move_type payment_state  company_id partner_id  \
# 9324  153724  IBR202300032  out_invoice    in_payment          12       8987
#
#       currency_id  amount_total  amount_residual invoice_date  \
# 9324           33      1948.800            0.000   2024-10-22
#
#      invoice_date_due payment_dates                           company_name  \
# 9324       2024-11-21    29/11/2024  IBRANDS MEDIOS INTERACTIVOS DE MEXICO
#
#                                     partner_name currency_name
# 9324  ASALES, SERVICIOS DE MARKETING EN INTERNET           MXN

# %% [markdown]
# Convierto las facturas con estado de en proceso de pago en pagadas

# %%
invoices_df['payment_state'] = invoices_df['payment_state'].apply(lambda x: 'paid' if x == 'in_payment' else x)

# %%
invoices_df.to_pickle("invoices_cleanedv3.pkl")

# %% [markdown]
# **Facturas pagadas parcialmente**

# %%
invoices_df = pd.read_pickle("invoices_cleanedv3.pkl")

# %%
invoices_df['payment_state'].value_counts()
# Out:
# payment_state
# paid        19072
# not_paid     4839
# partial        20
# Name: count, dtype: int64

# %%
invoices_partial = invoices_df[invoices_df['payment_state'] == 'partial']
invoices_partial
# Out:
#            id             name    move_type payment_state  company_id  \
# 3033   189107   FVM/2025/00051  out_invoice       partial           6
# 3147   185076   FVM/2025/00023  out_invoice       partial           6
# 5031   178448   INT/2024/00026  out_invoice       partial           1
# 5035   174442   INT/2024/00022  out_invoice       partial           1
# 5109   174403   FVE/2024/03004  out_invoice       partial           3
# 10452  149233   FVE/2024/02077  out_invoice       partial           3
# 10467  149216   FVE/2024/02062  out_invoice       partial           3
# 11676  141878   FVE/2024/01812  out_invoice       partial           3
# 12124  139026     ELM202400377  out_invoice       partial           8
# 14217  115046      AMZN-2024-1  out_invoice       partial           3
# 14924  107004   INT/2024/00002  out_invoice       partial           1
# 15041  104262   FVE/2024/00656  out_invoice       partial           3
# 15414   98852     ELM202400107  out_invoice       partial           8
# 16750   84600   FVT/2023/00165  out_invoice       partial           7
# 19690   65548   FVT/2023/00138  out_invoice       partial           7
# 19691   65549   FVT/2023/00137  out_invoice       partial           7
# 21310   47707   FVE/2023/00842  out_invoice       partial           3
# 22506   27894   FVI/2023/00127  out_invoice       partial           2
# 22934   22732   FVE/2023/00224  out_invoice       partial           3
# 24104    9720  INV1/2022/00033  out_invoice       partial           3
#
#       partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 3033       13255            1       709.500          104.500   2025-02-07
# 3147        9294            1      4840.000         2420.000   2025-01-31
# 5031       13260            1     50609.590        25609.590   2024-12-31
# 5035          10            1    147254.400        30473.850   2024-12-31
# 5109       13260            1      6980.290            0.010   2024-12-31
# 12124  COMERCIALIZADORA ALMACENES GARCIA DE MEXICO           MXN
# 14217                       AMAZON INVOICING SPAIN           EUR
# 14924                       Kraz Data Solutions SL           EUR
# 15041              Factory Burger Hosteleria, S.L.           EUR
# 15414                               ONUS COMERCIAL           MXN
# 16750                             Equipzilla, S.L.           EUR
# 19690                       Buddyswim Europe, S.L.           EUR
# 19691         First Blunae Corporation Group, S.L.           EUR
# 21310              VTEX Ecommerce Platform Limited           EUR
# 22506                       Vitola Marketing, S.L.           EUR
# 22934                 Digital Lola Commerce S.A.U.           EUR
# 24104                             Equipzilla, S.L.           EUR

# %% [markdown]
# Voy a sacar las lineas de la factura para asegurarme de que realmente esten parcialmente pagadas

# %%
invoice_lines_partial = []
for id in invoices_partial['id']:
    lines = asyncio.run(data_retriever.get_invoice_line_by_invoice_id(invoice_id=id))
    print(f"Invoice ID: {id}, Lines retrieved: {len(lines)}")
    invoice_lines_partial.extend(lines)
invoice_lines_partial_df = pd.DataFrame(invoice_lines_partial)
# Out:
# Invoice ID: 189107, Lines retrieved: 3
# Invoice ID: 185076, Lines retrieved: 3
# Invoice ID: 178448, Lines retrieved: 3
# Invoice ID: 174442, Lines retrieved: 3
# Invoice ID: 174403, Lines retrieved: 5
# Invoice ID: 149233, Lines retrieved: 4
# Invoice ID: 149216, Lines retrieved: 3
# Invoice ID: 141878, Lines retrieved: 5
# Invoice ID: 139026, Lines retrieved: 3
# Invoice ID: 115046, Lines retrieved: 3
# Invoice ID: 107004, Lines retrieved: 3
# Invoice ID: 104262, Lines retrieved: 9
# Invoice ID: 98852, Lines retrieved: 3
# Invoice ID: 84600, Lines retrieved: 3
# Invoice ID: 65548, Lines retrieved: 3
# Invoice ID: 65549, Lines retrieved: 3
# Invoice ID: 47707, Lines retrieved: 2
# Invoice ID: 27894, Lines retrieved: 3
# Invoice ID: 22732, Lines retrieved: 3
# Invoice ID: 9720, Lines retrieved: 2

# %%
invoice_lines_partial_df['move_id'] = invoice_lines_partial_df['move_id'].apply(lambda x: x[0] if isinstance(x, list) else pd.NA)

# %%
invoice_lines_partial_df.head()
# Out:
#        id  move_id                                    product_id  quantity  \
# 0  630003   189107        [27, [PATROCINIOS (M4EC)] PATROCINIOS]     1.000
# 1  630004   189107                                         False     0.000
# 2  630005   189107                                         False     0.000
# 3  615480   185076  [24, [CONTENIDOS (M4eC)] CONTENIDOS PROPIOS]     1.000
# 4  615481   185076                                         False     0.000
#
#    price_unit tax_ids  reconciled  blocked date_maturity   debit   credit  \
# 0     586.360   [602]       False    False         False   0.000  586.360
# 1       0.000      []       False    False    2025-03-09 709.500    0.000
# 2       0.000      []       False    False         False   0.000  123.140
# 3    4000.000   [602]       False    False         False   0.000 4000.000
# 4       0.000      []       False    False         False   0.000  840.000
#
#     balance  amount_residual currency_id  \
# 0  -586.360            0.000    [1, EUR]
# 1   709.500          104.500    [1, EUR]
# 2  -123.140            0.000    [1, EUR]
# 3 -4000.000            0.000    [1, EUR]
# 4  -840.000            0.000    [1, EUR]
#
#                                     company_id  discount  discount_percentage  \
# 0  [6, Marketing4ecommerce Digital Content SL]     0.000                0.000
# 1  [6, Marketing4ecommerce Digital Content SL]     0.000                0.000
# 2  [6, Marketing4ecommerce Digital Content SL]     0.000                0.000
# 3  [6, Marketing4ecommerce Digital Content SL]     0.000                0.000
# 4  [6, Marketing4ecommerce Digital Content SL]     0.000                0.000
#
#    full_reconcile_id  is_downpayment  reconcile_model_id
# 0              False           False               False
# 1              False           False               False
# 2              False           False               False
# 3              False           False               False
# 4              False           False               False

# %% [markdown]
# No estan ni reconciliadas ni con 0 en el residuo por pagar, pero las facturas 174403, 149233, 139026, 104262 y 47707 tienen valores demasiado bajos por pagar, las voy a considerar como pagadas

# %%
for id in invoices_partial['id']:
    sum_balance = 0
    amount_total = invoices_partial[invoices_partial['id'] == id]['amount_total'].values[0]
    amount_residual = invoices_partial[invoices_partial['id'] == id]['amount_residual'].values[0]
    for line in invoice_lines_partial_df[invoice_lines_partial_df['move_id'] == id]['amount_residual']:
        sum_balance += line
    print(f"Invoice ID: {id}, Amount Total: {amount_total}, Amount Residual: {amount_residual}, Sum of Line Residuals: {sum_balance}")
# Out:
# Invoice ID: 189107, Amount Total: 709.5, Amount Residual: 104.5, Sum of Line Residuals: 104.5
# Invoice ID: 185076, Amount Total: 4840.0, Amount Residual: 2420.0, Sum of Line Residuals: 2420.0
# Invoice ID: 178448, Amount Total: 50609.59, Amount Residual: 25609.59, Sum of Line Residuals: 25609.59
# Invoice ID: 174442, Amount Total: 147254.4, Amount Residual: 30473.85, Sum of Line Residuals: 30473.85
# Invoice ID: 174403, Amount Total: 6980.29, Amount Residual: 0.01, Sum of Line Residuals: 0.01
# Invoice ID: 149233, Amount Total: 1394.58, Amount Residual: 0.01, Sum of Line Residuals: 0.01
# Invoice ID: 149216, Amount Total: 5445.0, Amount Residual: 3630.0, Sum of Line Residuals: 3630.0
# Invoice ID: 141878, Amount Total: 8167.5, Amount Residual: 2330.73, Sum of Line Residuals: 2330.73
# Invoice ID: 139026, Amount Total: 376924.09, Amount Residual: 0.09, Sum of Line Residuals: 0.08
# Invoice ID: 115046, Amount Total: 100.97, Amount Residual: 26.97, Sum of Line Residuals: 26.97
# Invoice ID: 107004, Amount Total: 6050.0, Amount Residual: 1769.97, Sum of Line Residuals: 1769.97
# Invoice ID: 104262, Amount Total: 7456.07, Amount Residual: 0.05, Sum of Line Residuals: 0.05
# Invoice ID: 98852, Amount Total: 99180.0, Amount Residual: 1740.43, Sum of Line Residuals: 1500.3700000000001
# Invoice ID: 84600, Amount Total: 2420.0, Amount Residual: 600.0, Sum of Line Residuals: 600.0
# Invoice ID: 65548, Amount Total: 2420.0, Amount Residual: 600.0, Sum of Line Residuals: 600.0
# Invoice ID: 65549, Amount Total: 2420.0, Amount Residual: 600.0, Sum of Line Residuals: 600.0
# Invoice ID: 47707, Amount Total: 7890.0, Amount Residual: 6.0, Sum of Line Residuals: 6.0
# Invoice ID: 27894, Amount Total: 239.58, Amount Residual: 78.96, Sum of Line Residuals: 78.96
# Invoice ID: 22732, Amount Total: 7852.9, Amount Residual: 6490.0, Sum of Line Residuals: 6490.0
# Invoice ID: 9720, Amount Total: 5050.26, Amount Residual: 3206.2, Sum of Line Residuals: 3206.2

# %%
to_paid_invoices = [174403, 149233, 139026, 104262, 47707]
invoices_df['payment_state'] = invoices_df.apply(lambda row: 'paid' if row['id'] in to_paid_invoices else row['payment_state'], axis=1)

# %% [markdown]
# Quedan 15 facturas parciales, dada la pequeña cantidad, no tiene sentido hacer una clase únicamente para las parcialmente pagadas, por tanto, las moveré a la clase de no pagadas

# %%
invoices_df['payment_state'].value_counts()
# Out:
# payment_state
# paid        19077
# not_paid     4839
# partial        15
# Name: count, dtype: int64

# %%
invoices_df['payment_state'] = invoices_df['payment_state'].apply(lambda x: 'not_paid' if x == 'partial' else x)
invoices_df['payment_state'].value_counts()
# Out:
# payment_state
# paid        19077
# not_paid     4854
# Name: count, dtype: int64

# %% [markdown]
# **Pagadas**

# %% [markdown]
# Simplemente voy a comprobar que realmente esten pagadas a partir de las lineas de la factura y parece que todas estan pagadas, algunos pequeños valores en amount_residual no relevantes

# %%
error_paid_invoices = []
paid_invoices = invoices_df[invoices_df['payment_state'] == 'paid']
for id in paid_invoices['id']:
    lines = asyncio.run(data_retriever.get_invoice_line_by_invoice_id(invoice_id=id))
    for line in lines:
        amount_residual = line['amount_residual']
        if amount_residual > 0:
            print(f"Invoice ID: {id}, Line ID: {line['id']}, Amount Residual: {amount_residual}")
            error_paid_invoices.append(id)
print(f"Total paid invoices with residual amount > 0: {len(error_paid_invoices)}")
# Out:
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "c:\Users\Ismae\miniconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001E8F27A8980> is already entered
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "c:\Users\Ismae\miniconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001E8F27A8980> is already entered
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "c:\Users\Ismae\miniconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001E8F27A8980> is already entered
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "c:\Users\Ismae\miniconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001E8F27A8980> is already entered
# Invoice ID: 174403, Line ID: 580724, Amount Residual: 0.01
# Invoice ID: 149233, Line ID: 493136, Amount Residual: 0.01
# Invoice ID: 139026, Line ID: 458926, Amount Residual: 0.09

# %% [markdown]
# **No pagadas**

# %% [markdown]
# Comprobaré que realmente no esten pagadas

# %%
invoice_lines_df_original['move_id'] = invoice_lines_df_original['move_id'].apply(lambda x: x[0] if isinstance(x, list) else pd.NA)

# %% [markdown]
# Parece que todas estan sin pagar, ni estan reconciliadas ni tienen amount_residual != 0 (los resultados del código de abajo, mirando caso por caso, realmente no estan pagadas las facturas)

# %%
# Invoice ID: 165420, Line ID: 567995, Amount Residual: 0.0
# Invoice ID: 169102, Line ID: 560961, Amount Residual: 0.0
# Invoice ID: 164863, Line ID: 545554, Amount Residual: 0.0
# Invoice ID: 136604, Line ID: 451809, Amount Residual: 0.0
# Invoice ID: 128704, Line ID: 422977, Amount Residual: 0.0
# Invoice ID: 107130, Line ID: 353675, Amount Residual: 0.0
# Invoice ID: 79758, Line ID: 258780, Amount Residual: 0.0
# Invoice ID: 19326, Line ID: 42638, Amount Residual: 0.0

# %%
invoice_lines_df_original[invoice_lines_df_original["move_id"] == 185257]
# Out:
#           id  move_id                                product_id  quantity  \
# 9178  616200   185257  [99, [ACADEMY DIRECT] FORMACION DIRECTA]     1.000
# 9179  616201   185257                                     False     0.000
# 9180  616202   185257                                     False     0.000
#
#       price_unit tax_ids  reconciled  blocked date_maturity    debit   credit  \
# 9178    4760.000   [902]       False    False         False    0.000 4760.000
# 9179       0.000      []       False    False    2025-03-19 5759.600    0.000
# 9180       0.000      []       False    False         False    0.000  999.600
#
#        balance  amount_residual currency_id                  company_id  \
# 9178 -4760.000            0.000    [1, EUR]  [11, DigitalPla2021, S.L.]
# 9179  5759.600         5759.600    [1, EUR]  [11, DigitalPla2021, S.L.]
# 9180  -999.600            0.000    [1, EUR]  [11, DigitalPla2021, S.L.]
#
#       discount  discount_percentage full_reconcile_id  is_downpayment  \
# 9178     0.000                0.000             False           False
# 9179     0.000                0.000             False           False
# 9180     0.000                0.000             False           False
#
#       reconcile_model_id
# 9178               False
# 9179               False
# 9180               False

# %%
invoices_df.to_pickle("invoices_cleanedv4.pkl")

# %% [markdown]
# #### partner_id && partner name

# %% [markdown]
# 4 facturas sin partner, voy a investigar si puedo sacar algo de las lineas de las facturas

# %%
invoices_df['partner_id'].info()
print(invoices_df['partner_id'].isna().sum())
print(invoices_df['partner_id'].nunique())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 23931 entries, 0 to 24287
# Series name: partner_id
# Non-Null Count  Dtype
# --------------  -----
# 23927 non-null  object
# dtypes: object(1)
# memory usage: 373.9+ KB
# 4
# 1517

# %%
invoices_without_partner = invoices_df[invoices_df['partner_id'].isna()]
invoices_without_partner
# Out:
#           id            name    move_type payment_state  company_id  \
# 1164  197175   FACT-2025-XYZ  out_invoice      not_paid           7
# 1165  197174   FACT-2025-XYZ  out_invoice      not_paid           1
# 1166  197173   FACT-2025-XYZ  out_invoice      not_paid           1
# 3105  181418  INT/2025/00001  out_invoice      not_paid           8
#
#      partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 1164       <NA>            1         0.000            0.000         <NA>
# 1165       <NA>            1         0.000            0.000         <NA>
# 1166       <NA>            1         0.000            0.000         <NA>
# 3105       <NA>           33         0.000            0.000         <NA>
#
#      invoice_date_due payment_dates                        company_name  \
# 1164       2025-07-23          <NA>           Tandem Trade Marketing SL
# 1165       2025-07-23          <NA>  Grupo Viko Digital Marketing, S.A.
# 1166       2025-07-23          <NA>  Grupo Viko Digital Marketing, S.A.
# 3105       2025-02-03          <NA>     INICIATIVAS VIRTUALES DE MEXICO
#
#      partner_name currency_name
# 1164         <NA>           EUR
# 1165         <NA>           EUR
# 1166         <NA>           EUR
# 3105         <NA>           MXN

# %% [markdown]
# No tienen lineas de factura asociadas, asumo que son pruebas o errores, las elimino y ya

# %%
lines_temp_df = pd.DataFrame()
invoice_lines_df = invoice_lines_df_original.copy()
for id in invoices_without_partner['id']:
    lines = invoice_lines_df[invoice_lines_df['move_id'] == id]
    print(lines)
    lines_temp_df = pd.concat([lines_temp_df, lines], ignore_index=True)
lines_temp_df
# Out:
# Empty DataFrame
# Columns: [id, move_id, product_id, quantity, price_unit, tax_ids, reconciled, blocked, date_maturity, debit, credit, balance, amount_residual, currency_id, company_id, discount, discount_percentage, full_reconcile_id, is_downpayment, reconcile_model_id]
# Index: []
# Empty DataFrame
# Columns: [id, move_id, product_id, quantity, price_unit, tax_ids, reconciled, blocked, date_maturity, debit, credit, balance, amount_residual, currency_id, company_id, discount, discount_percentage, full_reconcile_id, is_downpayment, reconcile_model_id]
# Index: []
# Empty DataFrame
# Columns: [id, move_id, product_id, quantity, price_unit, tax_ids, reconciled, blocked, date_maturity, debit, credit, balance, amount_residual, currency_id, company_id, discount, discount_percentage, full_reconcile_id, is_downpayment, reconcile_model_id]
# Index: []
# Empty DataFrame
# Columns: [id, move_id, product_id, quantity, price_unit, tax_ids, reconciled, blocked, date_maturity, debit, credit, balance, amount_residual, currency_id, company_id, discount, discount_percentage, full_reconcile_id, is_downpayment, reconcile_model_id]
# Index: []
# Empty DataFrame
# Columns: [id, move_id, product_id, quantity, price_unit, tax_ids, reconciled, blocked, date_maturity, debit, credit, balance, amount_residual, currency_id, company_id, discount, discount_percentage, full_reconcile_id, is_downpayment, reconcile_model_id]
# Index: []

# %%
invoices_df = invoices_df.dropna(subset=['partner_id'])

# %% [markdown]
# Ahora con el partner name y ya estaria

# %%
invoices_df['partner_name'].info()
print(invoices_df['partner_name'].isna().sum())
print(invoices_df['partner_name'].nunique())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 23927 entries, 0 to 24287
# Series name: partner_name
# Non-Null Count  Dtype
# --------------  -----
# 23927 non-null  object
# dtypes: object(1)
# memory usage: 373.9+ KB
# 0
# 1516

# %%
invoices_df.to_pickle("invoices_cleanedv4.pkl")

# %% [markdown]
# #### amount_total y amount_residual

# %%
invoices_df = pd.read_pickle("invoices_cleanedv4.pkl")

# %% [markdown]
# Valores muy grandes (probablemente por la moneda), alta concentración de facturas de bajo importe, algunas facturas con valores erroneos en amount_total (0?)

# %%
invoices_df[['amount_total', 'amount_residual']].describe()
# Out:
#        amount_total  amount_residual
# count     23927.000        23927.000
# mean      17621.277         8812.942
# std     1150393.864      1148984.899
# min           0.000            0.000
# 25%          12.000            0.000
# 50%          40.010            0.000
# 75%        2297.440            0.000
# max   177676632.000    177676632.000

# %%
invoices_df[invoices_df['amount_total'] == 0]
# Out:
#           id            name    move_type payment_state  company_id  \
# 2555  195207  FVC/2025/00005  out_invoice          paid           1
# 2556  195204  FVC/2025/00004  out_invoice          paid           1
#
#      partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 2555      13926            1         0.000            0.000   2025-03-26
# 2556         14            1         0.000            0.000   2025-03-26
#
#      invoice_date_due payment_dates                        company_name  \
# 2555       2025-03-26          <NA>  Grupo Viko Digital Marketing, S.A.
# 2556       2025-03-26          <NA>  Grupo Viko Digital Marketing, S.A.
#
#                    partner_name currency_name
# 2555        Marketplaces Italia           EUR
# 2556  Tandem Trade Marketing SL           EUR

# %% [markdown]
# Las elimino

# %%
invoices_df = invoices_df.drop(invoices_df[invoices_df['amount_total'] == 0].index)

# %%
invoices_df[invoices_df['amount_total'] < 1]
# Out:
#            id            name    move_type payment_state  company_id  \
# 5136   173716  FVE/2024/02968  out_invoice          paid           3
# 7120   166010  FVM/2024/00439  out_invoice          paid           6
# 11519  142728  FVM/2024/00327  out_invoice          paid           6
#
#       partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 5136        8299            1         0.970            0.000   2024-12-31
# 7120       12731            1         0.360            0.000   2024-11-30
# 11519      12731            1         0.150            0.000   2024-08-31
#
#       invoice_date_due payment_dates                            company_name  \
# 5136        2025-03-01    06/03/2025                       Elogia Media S.L.
# 7120        2024-12-30    12/11/2024  Marketing4ecommerce Digital Content SL
# 11519       2024-09-30    13/08/2024  Marketing4ecommerce Digital Content SL
#
#                       partner_name currency_name
# 5136   Madz Digital Business, S.L.           EUR
# 7120                      Bitpanda           EUR
# 11519                     Bitpanda           EUR

# %%
invoices_df[['amount_total', 'amount_residual']].describe()
# Out:
#        amount_total  amount_residual
# count     23925.000        23925.000
# mean      17622.750         8813.679
# std     1150441.937      1149032.921
# min           0.150            0.000
# 25%          12.000            0.000
# 50%          40.150            0.000
# 75%        2297.790            0.000
# max   177676632.000    177676632.000

# %%
currencies_df = pd.DataFrame(asyncio.run(odoo_connection.search_read('res.currency', [], [], offset=0, limit=0)))

# %% [markdown]
# Los rates son erróneos o no actualizados...

# %%
# pip install pandas-datareader
currencies_df
# Out:
#     id name             full_name symbol   rate  inverse_rate  \
# 0    8  COP        Colombian peso      $  1.000         1.000
# 1    1  EUR                  Euro      €  1.000         1.000
# 2  142  GBP        Pound sterling      £  0.841         1.189
# 3   33  MXN          Mexican peso      $ 22.036         0.045
# 4   18  SEK         Swedish krona     kr 10.976         0.091
# 5    2  USD  United States dollar      $  1.089         0.919
#
#              rate_string                                           rate_ids  \
# 0   1 EUR = 1.000000 COP                                     [15031, 14958]
# 1                         [33684, 33689, 33694, 33699, 33704, 33709, 337...
# 2   1 EUR = 0.840780 GBP  [33681, 33686, 33691, 33696, 33701, 33706, 337...
# 3  1 EUR = 22.036400 MXN  [33740, 33744, 33672, 33676, 33683, 33688, 336...
# 4  1 EUR = 10.976500 SEK  [33682, 33687, 33692, 33697, 33702, 33707, 337...
# 5   1 EUR = 1.088600 USD  [33680, 33685, 33690, 33695, 33700, 33705, 337...
#
#    rounding  decimal_places  ...  currency_subunit_label  \
# 0     0.010               2  ...                Centavos
# 1     0.010               2  ...                   Cents
# 2     0.010               2  ...                   Penny
# 3     0.010               2  ...                Centavos
# 4     0.010               2  ...                     Ore
# 5     0.010               2  ...                   Cents
#
#   is_current_company_currency        __last_update display_name    create_uid  \
# 0                       False  2024-04-16 11:58:19          COP  [1, OdooBot]
# 1                        True  2024-06-19 08:37:47          EUR         False
# 2                       False  2023-04-05 11:39:53          GBP  [1, OdooBot]
# 3                       False  2023-07-06 14:47:55          MXN  [1, OdooBot]
# 4                       False  2025-03-05 12:14:29          SEK  [1, OdooBot]
# 5                       False  2023-07-18 12:35:52          USD  [1, OdooBot]
#
#            create_date                write_uid           write_date  \
# 0  2022-12-09 14:09:20  [6, Roger Regales Coll]  2024-04-16 11:58:19
# 1                False       [2, Administrator]  2024-06-19 08:37:47
# 2  2022-12-09 14:09:20       [2, Administrator]  2023-04-05 11:39:53
# 3  2022-12-09 14:09:20  [6, Roger Regales Coll]  2023-07-06 14:47:55
# 4  2022-12-09 14:09:20  [6, Roger Regales Coll]  2025-03-05 12:14:29
# 5  2022-12-09 14:09:20  [6, Roger Regales Coll]  2023-07-18 12:35:52
#
#   display_rounding_warning l10n_mx_edi_decimal_places
# 0                    False                          2
# 1                    False                          2
# 2                    False                          2
# 3                    False                          2
# 4                    False                          2
# 5                    False                          2
#
# [6 rows x 24 columns]

# %%
invoices_df['currency_name'].unique()
# Out:
# array(['EUR', 'SEK', 'MXN', 'USD', 'GBP', 'COP'], dtype=object)

# %% [markdown]
# Usaré los datos del banco central europeo

# %%
c = CurrencyRates()

rates = {}
rates['COP'] = 0.00022  # Valor fijo temporal
for currency in currencies_df['name']:
    if currency != 'EUR':
        try:
            rate = c.get_rate(currency, 'EUR')
            rates[currency] = rate
        except Exception as e:
            print(f"Error retrieving rate for {currency}: {e}")

invoices_df['amount_total_eur'] = invoices_df.apply(lambda row: row['amount_total'] * rates.get(row['currency_name'], 1) if row['currency_name'] != 'EUR' else row['amount_total'], axis=1)
invoices_df['amount_residual_eur'] = invoices_df.apply(lambda row: row['amount_residual'] * rates.get(row['currency_name'], 1) if row['currency_name'] != 'EUR' else row['amount_residual'], axis=1)
# Out:
# Error retrieving rate for COP: Currency Rates Source Not Ready

# %%
invoices_df.to_pickle("invoices_cleanedv5.pkl")

# %%
invocies_df = pd.read_pickle("invoices_cleanedv5.pkl")

# %%
invoices_df[['amount_total_eur', 'amount_residual_eur']].describe()
# Out:
#        amount_total_eur  amount_residual_eur
# count         23885.000            23885.000
# mean           2457.694              222.422
# std            9039.125             2440.760
# min               0.150                0.000
# 25%              12.000                0.000
# 50%              39.990                0.000
# 75%            1887.600                0.000
# max          633574.150           131605.930

# %% [markdown]
# #### invoice_date y invoice_date_due

# %%
invoices_df = convert_to_datetime(invoices_df, ['invoice_date', 'invoice_date_due'])
# Out:
# C:\Users\Ismae\AppData\Local\Temp\ipykernel_12556\3345669672.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\Ismae\AppData\Local\Temp\ipykernel_12556\3345669672.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
invoices_df[['invoice_date', 'invoice_date_due']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23885 entries, 0 to 24287
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   invoice_date      23885 non-null  datetime64[ns]
#  1   invoice_date_due  23885 non-null  datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 559.8 KB

# %% [markdown]
# invoice_date tiene un null, voy a verlo

# %%
invoices_df[invoices_df['invoice_date'].isna()]
# Out:
#           id            name    move_type payment_state  company_id  \
# 1765  196522  FVV/2025/00001  out_invoice      not_paid           1
#
#      partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 1765       8571            1        10.000           10.000          NaT
#
#      invoice_date_due payment_dates                        company_name  \
# 1765       2025-06-05          <NA>  Grupo Viko Digital Marketing, S.A.
#
#                 partner_name currency_name  amount_total_eur  \
# 1765  Google Ireland Limited           EUR            10.000
#
#       amount_residual_eur
# 1765               10.000

# %% [markdown]
# No tiene lineas de factura elimino y ya está

# %%
invoices_lines = pd.read_pickle("invoice_lines.pkl")
invoices_lines[invoices_lines_in_payment['move_id'] == 196522]
# Out:
# Empty DataFrame
# Columns: [id, move_id, product_id, quantity, price_unit, tax_ids, reconciled, blocked, date_maturity, debit, credit, balance, amount_residual, currency_id, company_id, discount, discount_percentage, full_reconcile_id, is_downpayment, reconcile_model_id]
# Index: []

# %%
invoices_df = invoices_df.dropna(subset=['invoice_date'])

# %%
invoices_df.isna().sum()
# Out:
# id                        0
# name                      0
# move_type                 0
# payment_state             0
# company_id                0
# partner_id                0
# currency_id               0
# amount_total              0
# amount_residual           0
# invoice_date              0
# invoice_date_due          0
# payment_dates          4876
# company_name              0
# partner_name              0
# currency_name             0
# amount_total_eur          0
# amount_residual_eur       0
# dtype: int64

# %% [markdown]
# #### Payment_dates

# %% [markdown]
# Muchos nulls en payment_dates principalmente por datos censurados, de momento comprobaré que no haya ninguna factura pagada sin fecha

# %%
invoices_paid_without_date = invoices_df[(invoices_df['payment_dates'].isna()) & (invoices_df['payment_state'] == 'paid')]
len(invoices_paid_without_date)
# Out:
# 39

# %% [markdown]
# 39 facturas que están pagadas pero sin fecha, voy a intentar buscar las lineas

# %%
lines_paid_without_date = invoices_lines[invoices_lines['move_id'].isin(invoices_paid_without_date['id'])]
lines_paid_without_date
# Out:
# Empty DataFrame
# Columns: [id, move_id, product_id, quantity, price_unit, tax_ids, reconciled, blocked, date_maturity, debit, credit, balance, amount_residual, currency_id, company_id, discount, discount_percentage, full_reconcile_id, is_downpayment, reconcile_model_id]
# Index: []

# %% [markdown]
# No tienen lineas, por tanto como si no existiesen

# %%
invoices_df = invoices_df[~invoices_df['id'].isin(invoices_paid_without_date['id'])]

# %%
invoices_df.to_pickle("invoices_cleanedv6.pkl")

# %%
invoices_df = pd.read_pickle("invoices_cleanedv6.pkl")

# %% [markdown]
# Facturas no pagadas pero con fecha:

# %%
invoices_unpaid_with_date = invoices_df[(~invoices_df['payment_dates'].isna()) & (invoices_df['payment_state'] == 'unpaid')]
invoices_unpaid_with_date
# Out:
# Empty DataFrame
# Columns: [id, name, move_type, payment_state, company_id, partner_id, currency_id, amount_total, amount_residual, invoice_date, invoice_date_due, payment_dates, company_name, partner_name, currency_name, amount_total_eur, amount_residual_eur]
# Index: []

# %% [markdown]
# Fechas erróneas o múltiples plazos

# %%
invoices_multiple_payment_dates = invoices_df[~invoices_df['payment_dates'].isna() & ~invoices_df['payment_dates'].astype(str).str.match(r'^\d{2}/\d{2}/\d{4}$')]
invoices_multiple_payment_dates
# Out:
#            id             name    move_type payment_state  company_id  \
# 3150   185073   FVM/2025/00020  out_invoice          paid           6
# 5035   174442   INT/2024/00022  out_invoice      not_paid           1
# 7082   166310   INT/2024/00021  out_invoice          paid           1
# 7293   164498   FVE/2024/02609  out_invoice          paid           3
# 8536   156709   MAC/2024/00046  out_invoice          paid          11
# ...       ...              ...          ...           ...         ...
# 24094    9722  INV1/2022/00035  out_invoice          paid           3
# 24131   12241  INV1/2022/00027  out_invoice          paid           2
# 24185   13094  INV1/2022/00016  out_invoice          paid           8
# 24207   13090  INV1/2022/00012  out_invoice          paid           8
# 24271   12475  INV1/2022/00001  out_invoice          paid           1
#
#       partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 3150        7866            1        37.490            0.000   2025-01-31
# 5035          10            1    147254.400        30473.850   2024-12-31
# 7082          10            1    155428.050            0.000   2024-11-30
# 7293        8663            1      8654.240            0.000   2024-11-30
# 8536       14410            1      6655.000            0.000   2024-11-04
# ...          ...          ...           ...              ...          ...
# 24094       8073            1      5808.000            0.000   2022-12-31
# 24131       8935            2       251.630            0.000   2022-12-31
# 24185       8974           33     37700.000            0.000   2022-12-05
# 24207       8974           33     37700.000            0.000   2022-12-05
# 24271         12            1     24200.000            0.000   2022-12-31
#
#       invoice_date_due                                      payment_dates  \
# 3150        2025-03-02                             26/02/2025, 24/02/2025
# 5035        2024-12-31  27/12/2024, 27/12/2024, 27/12/2024, 16/12/2024...
# 7082        2024-12-16  29/11/2024, 29/11/2024, 25/11/2024, 08/11/2024...
# 7293        2025-01-29                             02/01/2025, 02/12/2024
# 8536        2024-12-12                             12/12/2024, 19/11/2024
# ...                ...                                                ...
# 24094       2023-02-26                             10/07/2023, 19/04/2023
# 24131       2023-03-01                             26/02/2023, 13/02/2023
# 24185       2023-02-20     10/11/2023, 20/10/2023, 11/08/2023, 22/05/2023
# 24207       2023-02-20                             22/05/2023, 14/04/2023
# 24271       2023-02-14                             06/05/2023, 28/04/2023
#
#                                  company_name             partner_name  \
# 3150   Marketing4ecommerce Digital Content SL  Nextalia Ventures, S.L.
# 5035       Grupo Viko Digital Marketing, S.A.        Elogia Media S.L.
# 7082       Grupo Viko Digital Marketing, S.A.        Elogia Media S.L.
# 7293                        Elogia Media S.L.      Irmaos Vila Nova SA
# 8536                     DigitalPla2021, S.L.         Playbrands, S.L.
# ...                                       ...                      ...
# 24094                       Elogia Media S.L.  Simer Grumerosa, S.L.U.
# 24131          Ibrands Medios Interactivos SL  Soicos International AG
# 24185         INICIATIVAS VIRTUALES DE MEXICO           IBC OPERATIONS
# 24207         INICIATIVAS VIRTUALES DE MEXICO           IBC OPERATIONS
# 24271      Grupo Viko Digital Marketing, S.A.   Kraz Data Solutions SL
#
#       currency_name  amount_total_eur  amount_residual_eur
# 3150            EUR            37.490                0.000
# 5035            EUR        147254.400            30473.850
# 7082            EUR        155428.050                0.000
# 7293            EUR          8654.240                0.000
# 8536            EUR          6655.000                0.000
# ...             ...               ...                  ...
# 24094           EUR          5808.000                0.000
# 24131           USD           217.372                0.000
# 24185           MXN          1781.363                0.000
# 24207           MXN          1781.363                0.000
# 24271           EUR         24200.000                0.000
#
# [110 rows x 17 columns]

# %% [markdown]
# Para multiples plazos de momento simplemente me quedaré con la última fecha y invoice_date_due:

# %%
invoices_df["payment_dates"] = (invoices_df["payment_dates"].astype(str).str.split(r",\s*").str[0])

# %%
invoices_df[invoices_df['id'].isin(invoices_multiple_payment_dates['id'])]
# Out:
#            id             name    move_type payment_state  company_id  \
# 3150   185073   FVM/2025/00020  out_invoice          paid           6
# 5035   174442   INT/2024/00022  out_invoice      not_paid           1
# 7082   166310   INT/2024/00021  out_invoice          paid           1
# 7293   164498   FVE/2024/02609  out_invoice          paid           3
# 8536   156709   MAC/2024/00046  out_invoice          paid          11
# ...       ...              ...          ...           ...         ...
# 24094    9722  INV1/2022/00035  out_invoice          paid           3
# 24131   12241  INV1/2022/00027  out_invoice          paid           2
# 24185   13094  INV1/2022/00016  out_invoice          paid           8
# 24207   13090  INV1/2022/00012  out_invoice          paid           8
# 24271   12475  INV1/2022/00001  out_invoice          paid           1
#
#       partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 3150        7866            1        37.490            0.000   2025-01-31
# 5035          10            1    147254.400        30473.850   2024-12-31
# 7082          10            1    155428.050            0.000   2024-11-30
# 7293        8663            1      8654.240            0.000   2024-11-30
# 8536       14410            1      6655.000            0.000   2024-11-04
# ...          ...          ...           ...              ...          ...
# 24094       8073            1      5808.000            0.000   2022-12-31
# 24131       8935            2       251.630            0.000   2022-12-31
# 24185       8974           33     37700.000            0.000   2022-12-05
# 24207       8974           33     37700.000            0.000   2022-12-05
# 24271         12            1     24200.000            0.000   2022-12-31
#
#       invoice_date_due payment_dates                            company_name  \
# 3150        2025-03-02    26/02/2025  Marketing4ecommerce Digital Content SL
# 5035        2024-12-31    27/12/2024      Grupo Viko Digital Marketing, S.A.
# 7082        2024-12-16    29/11/2024      Grupo Viko Digital Marketing, S.A.
# 7293        2025-01-29    02/01/2025                       Elogia Media S.L.
# 8536        2024-12-12    12/12/2024                    DigitalPla2021, S.L.
# ...                ...           ...                                     ...
# 24094       2023-02-26    10/07/2023                       Elogia Media S.L.
# 24131       2023-03-01    26/02/2023          Ibrands Medios Interactivos SL
# 24185       2023-02-20    10/11/2023         INICIATIVAS VIRTUALES DE MEXICO
# 24207       2023-02-20    22/05/2023         INICIATIVAS VIRTUALES DE MEXICO
# 24271       2023-02-14    06/05/2023      Grupo Viko Digital Marketing, S.A.
#
#                   partner_name currency_name  amount_total_eur  \
# 3150   Nextalia Ventures, S.L.           EUR            37.490
# 5035         Elogia Media S.L.           EUR        147254.400
# 7082         Elogia Media S.L.           EUR        155428.050
# 7293       Irmaos Vila Nova SA           EUR          8654.240
# 8536          Playbrands, S.L.           EUR          6655.000
# ...                        ...           ...               ...
# 24094  Simer Grumerosa, S.L.U.           EUR          5808.000
# 24131  Soicos International AG           USD           217.372
# 24185           IBC OPERATIONS           MXN          1781.363
# 24207           IBC OPERATIONS           MXN          1781.363
# 24271   Kraz Data Solutions SL           EUR         24200.000
#
#        amount_residual_eur
# 3150                 0.000
# 5035             30473.850
# 7082                 0.000
# 7293                 0.000
# 8536                 0.000
# ...                    ...
# 24094                0.000
# 24131                0.000
# 24185                0.000
# 24207                0.000
# 24271                0.000
#
# [110 rows x 17 columns]

# %%
invoices_df = convert_to_datetime(invoices_df, ['payment_dates'])

# %%
invoices_df.to_pickle("invoices_cleanedv6.pkl")

# %%
invoices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23885 entries, 0 to 24287
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   23885 non-null  int64
#  1   name                 23885 non-null  object
#  2   move_type            23885 non-null  object
#  3   payment_state        23885 non-null  object
#  4   company_id           23885 non-null  int64
#  5   partner_id           23885 non-null  object
#  6   currency_id          23885 non-null  int64
#  7   amount_total         23885 non-null  float64
#  8   amount_residual      23885 non-null  float64
#  9   invoice_date         23885 non-null  datetime64[ns]
#  10  invoice_date_due     23885 non-null  datetime64[ns]
#  11  payment_dates        19048 non-null  datetime64[ns]
#  12  company_name         23885 non-null  object
#  13  partner_name         23885 non-null  object
#  14  currency_name        23885 non-null  object
#  15  amount_total_eur     23885 non-null  float64
#  16  amount_residual_eur  23885 non-null  float64
# dtypes: datetime64[ns](3), float64(4), int64(3), object(7)
# memory usage: 3.3+ MB

# %% [markdown]
# #### Eliminación de facturas no útiles

# %% [markdown]
# Marketplace no sirve para predecir facturas

# %%
partners_df_original = pd.read_pickle("partners.pkl")
partners_df_original = odoo_missing_values_to_null(partners_df_original)
partners_df_original = partners_df_original.dropna(subset=['name'])

marketplace_clients = partners_df_original[partners_df_original['name'].str.contains("Marketplace")]
marketplace_clients_list = marketplace_clients['id'].values.tolist()
marketplace_clients_list
# Out:
# Index(['name', 'email', 'phone', 'street', 'city', 'zip', 'country_id',
#        'category_id', 'company_type', 'company_id', 'industry_id', 'vat',
#        'invoice_ids', 'trust', 'unpaid_invoice_ids'],
#       dtype='object')
# C:\Users\Ismae\AppData\Local\Temp\ipykernel_22320\434508603.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[object_cols] = df[object_cols].applymap(lambda x: np.nan if x == [] else x)
# [14950,
#  14967,
#  15029,
#  14960,
#  14951,
#  14957,
#  14968,
#  15028,
#  14961,
#  14969,
#  14958,
#  14962,
#  14970,
#  14971,
#  14952,
#  14963,
#  15030,
#  14959,
#  14964,
#  14972,
#  14973,
#  14953,
#  14965,
#  14974,
#  14954,
#  14966,
#  13925,
#  14030,
#  14617,
#  10892,
#  13924,
#  13926,
#  9935]

# %%
invoices_df = pd.read_pickle("invoices_cleanedv6.pkl")
invoices_df = invoices_df[~invoices_df['partner_id'].isin(marketplace_clients_list)]
invoices_df.to_pickle("invoices_cleanedv7.pkl")

# %% [markdown]
# ### 1.2.3. res.partner

# %%
partners_df = pd.read_pickle("partners.pkl")

# %%
partners_spain = partners_df[partners_df['country_id'].str[0] == 68]
partners_spain['vat'].to_csv("partners_spain_ids.csv", index=False)

# %% [markdown]
# Convierto [], "" y False en objetos a null

# %%
partners_df = odoo_missing_values_to_null(partners_df)
# Out:
# Index(['name', 'email', 'phone', 'street', 'city', 'zip', 'country_id',
#        'category_id', 'company_type', 'company_id', 'industry_id', 'vat',
#        'invoice_ids', 'trust', 'unpaid_invoice_ids'],
#       dtype='object')
# C:\Users\Ismae\AppData\Local\Temp\ipykernel_28916\434508603.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[object_cols] = df[object_cols].applymap(lambda x: np.nan if x == [] else x)

# %%
partners_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1631 non-null   int64
#  1   name                   1630 non-null   object
#  2   email                  281 non-null    object
#  3   phone                  12 non-null     object
#  4   street                 1567 non-null   object
#  5   city                   1549 non-null   object
#  6   zip                    1551 non-null   object
#  7   country_id             1616 non-null   object
#  8   customer_rank          1631 non-null   int64
#  9   supplier_rank          1631 non-null   int64
#  10  category_id            284 non-null    object
#  11  is_company             1631 non-null   bool
#  12  company_type           1631 non-null   object
#  13  company_id             569 non-null    object
#  14  credit                 1631 non-null   float64
#  15  credit_limit           1631 non-null   float64
#  16  industry_id            1 non-null      object
#  17  vat                    1461 non-null   object
#  18  invoice_ids            1551 non-null   object
#  19  total_due              1631 non-null   float64
#  20  total_invoiced         1631 non-null   float64
#  21  total_overdue          1631 non-null   float64
#  22  trust                  1631 non-null   object
#  23  unpaid_invoice_ids     128 non-null    object
#  24  unpaid_invoices_count  1631 non-null   int64
# dtypes: bool(1), float64(5), int64(4), object(15)
# memory usage: 307.5+ KB

# %%
partners_df.isna().sum()
# Out:
# id                          0
# name                        1
# email                    1350
# phone                    1619
# street                     64
# city                       82
# zip                        80
# country_id                 15
# customer_rank               0
# supplier_rank               0
# category_id              1347
# is_company                  0
# company_type                0
# company_id               1062
# credit                      0
# credit_limit                0
# industry_id              1630
# vat                       170
# invoice_ids                80
# total_due                   0
# total_invoiced              0
# total_overdue               0
# trust                       0
# unpaid_invoice_ids       1503
# unpaid_invoices_count       0
# dtype: int64

# %% [markdown]
# A simple vista:
# - email: prácticamente vacio para la mayoria de clientes
# - telefono, category_id, company_id, industry_id, unpaid_invoice_ids: vacio
# - una empresa sin nombre
# - varios nulls en street, city, zip, country_id, vat y invoice_ids

# %% [markdown]
# Elimino las columnas email, phone, category_id, company_id, industry_id y unpaid_invoice_ids, supplier_rank (no sirve)

# %%
partners_df = partners_df.drop(columns=['email', 'phone', 'category_id', 'company_id', 'industry_id', 'unpaid_invoice_ids', 'supplier_rank'])
partners_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1631 non-null   int64
#  1   name                   1630 non-null   object
#  2   street                 1567 non-null   object
#  3   city                   1549 non-null   object
#  4   zip                    1551 non-null   object
#  5   country_id             1616 non-null   object
#  6   customer_rank          1631 non-null   int64
#  7   is_company             1631 non-null   bool
#  8   company_type           1631 non-null   object
#  9   credit                 1631 non-null   float64
#  10  credit_limit           1631 non-null   float64
#  11  vat                    1461 non-null   object
#  12  invoice_ids            1551 non-null   object
#  13  total_due              1631 non-null   float64
#  14  total_invoiced         1631 non-null   float64
#  15  total_overdue          1631 non-null   float64
#  16  trust                  1631 non-null   object
#  17  unpaid_invoices_count  1631 non-null   int64
# dtypes: bool(1), float64(5), int64(3), object(9)
# memory usage: 218.3+ KB

# %%
partners_df[['credit', 'credit_limit', 'total_due', 'total_invoiced', 'total_overdue', 'unpaid_invoices_count']].describe()
# Out:
#           credit  credit_limit  total_due  total_invoiced  total_overdue  \
# count   1631.000      1631.000   1631.000        1631.000       1631.000
# mean    1248.749         0.000   1248.749       30794.313       1248.749
# std     9944.027         0.000   9944.027      154444.803       9944.027
# min   -12507.000         0.000 -12507.000         -19.500     -12507.000
# 25%        0.000         0.000      0.000          39.980          0.000
# 50%        0.000         0.000      0.000         800.000          0.000
# 75%        0.000         0.000      0.000        7714.865          0.000
# max   283217.330         0.000 283217.330     3351155.510     283217.330
#
#        unpaid_invoices_count
# count               1631.000
# mean                   0.302
# std                    2.618
# min                    0.000
# 25%                    0.000
# 50%                    0.000
# 75%                    0.000
# max                   84.000

# %% [markdown]
# credit_limit y unpaid_invoices_count no sirven

# %%
partners_df = partners_df.drop(columns=['credit_limit', 'unpaid_invoices_count'])
partners_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1631 non-null   int64
#  1   name            1630 non-null   object
#  2   street          1567 non-null   object
#  3   city            1549 non-null   object
#  4   zip             1551 non-null   object
#  5   country_id      1616 non-null   object
#  6   customer_rank   1631 non-null   int64
#  7   is_company      1631 non-null   bool
#  8   company_type    1631 non-null   object
#  9   credit          1631 non-null   float64
#  10  vat             1461 non-null   object
#  11  invoice_ids     1551 non-null   object
#  12  total_due       1631 non-null   float64
#  13  total_invoiced  1631 non-null   float64
#  14  total_overdue   1631 non-null   float64
#  15  trust           1631 non-null   object
# dtypes: bool(1), float64(4), int64(2), object(9)
# memory usage: 192.9+ KB

# %%
partners_df[~partners_df['is_company'] & partners_df['vat'].isna()]
# Out:
#          id                       name  \
# 8     10970              Aaron Escobar
# 12    12023             Abel Hernández
# 35     9875               Adolfo Arana
# 36     9876              Adolfo Téllez
# 61    11311             Alba Castellet
# ...     ...                        ...
# 1537  12699                        Upf
# 1538  10979  uping.alejandro@gmail.com
# 1543   9917             Valentin Salas
# 1569  13577     Vitola Marketing, S.L.
# 1616  10138          Yariendy Sandoval
#
#                                         street                   city     zip  \
# 8                               Cuauhtemoc 123       Ciudad de México   16090
# 12                          Caldas Da Raihna 6                Badajoz    6011
# 35    Calle de Isabel Colbrand 18 Portal B 3º2                 Madrid   28050
# 36      Calle General Álvarez de Castro 36 2ºA                 Madrid   28010
# 61                Gran Vía Corts Catalanes 672              Barcelona   08010
# ...                                        ...                    ...     ...
# 1537                                      <NA>                   <NA>    <NA>
# 1538                     Cumbres francesas 112              Monterrey   64820
# 1543                           Montsant nave 6  Sant Fruitós de Bages   08272
# 1569                                      <NA>                   <NA>    <NA>
# 1616                            Calle 3n 2e-53                 Cucuta  540001
#
#           country_id  customer_rank  is_company company_type  credit   vat  \
# 8      [156, Mexico]              2       False       person   0.000  <NA>
# 12       [68, Spain]              1       False       person   0.000  <NA>
# 35       [68, Spain]              6       False       person   0.000  <NA>
# 36       [68, Spain]              3       False       person   0.000  <NA>
# 61       [68, Spain]              1       False       person   0.000  <NA>
# ...              ...            ...         ...          ...     ...   ...
# 1537            <NA>              1       False       person   0.000  <NA>
# 1538   [156, Mexico]              2       False       person   0.000  <NA>
# 1543     [68, Spain]              1       False       person   0.000  <NA>
# 1569            <NA>              2       False       person   0.000  <NA>
# 1616  [49, Colombia]              2       False       person   0.000  <NA>
#
#                                invoice_ids  total_due  total_invoiced  \
# 8                    [63361, 63691, 55911]      0.000          39.980
# 12                          [77026, 93888]      0.000         199.000
# 35    [103699, 44931, 31896, 24444, 24406]      0.000          36.000
# 36                   [24470, 24432, 24392]      0.000         119.970
# 61                          [63856, 70691]      0.000          90.000
# ...                                    ...        ...             ...
# 1537                                   NaN      0.000           0.000
# 1538                 [63345, 63684, 55930]      0.000          39.980
# 1543                               [24391]      0.000          39.990
# 1569                                   NaN      0.000           0.000
# 1616                        [44941, 31910]      0.000          78.000
#
#       total_overdue   trust
# 8             0.000  normal
# 12            0.000  normal
# 35            0.000  normal
# 36            0.000  normal
# 61            0.000  normal
# ...             ...     ...
# 1537          0.000  normal
# 1538          0.000  normal
# 1543          0.000  normal
# 1569          0.000  normal
# 1616          0.000  normal
#
# [170 rows x 16 columns]

# %% [markdown]
# Tenemos personas físicas y jurídicas, como trabajamos con operaciones B2B y por alguna razón en partners tienen contactos de personas trabajando en empresas que también estan ya incluidas, eliminaré todo lo que no sea company_type = company

# %%
partners_df['company_type'].value_counts()
# Out:
# company_type
# company    1370
# person      261
# Name: count, dtype: int64

# %%
partners_df = partners_df.drop(partners_df[partners_df['company_type'] != 'company'].index)
partners_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1370 entries, 0 to 1630
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1370 non-null   int64
#  1   name            1370 non-null   object
#  2   street          1367 non-null   object
#  3   city            1346 non-null   object
#  4   zip             1347 non-null   object
#  5   country_id      1366 non-null   object
#  6   customer_rank   1370 non-null   int64
#  7   is_company      1370 non-null   bool
#  8   company_type    1370 non-null   object
#  9   credit          1370 non-null   float64
#  10  vat             1370 non-null   object
#  11  invoice_ids     1365 non-null   object
#  12  total_due       1370 non-null   float64
#  13  total_invoiced  1370 non-null   float64
#  14  total_overdue   1370 non-null   float64
#  15  trust           1370 non-null   object
# dtypes: bool(1), float64(4), int64(2), object(9)
# memory usage: 172.6+ KB

# %% [markdown]
# customer_rank tampoco sirve, todos son customers por como se extraen

# %%
partners_df = partners_df.drop('customer_rank', axis=1)

# %% [markdown]
# is_company tampoco ya hemos filtrado por tipo company

# %%
partners_df['is_company'].value_counts()
# Out:
# is_company
# True    1370
# Name: count, dtype: int64

# %%
partners_df = partners_df.drop(columns=['is_company'])

# %% [markdown]
# #### trust

# %% [markdown]
# Demasiada poca información, no sirve

# %%
partners_df['trust'].value_counts()
# Out:
# trust
# normal    1368
# good         1
# bad          1
# Name: count, dtype: int64

# %%
partners_df = partners_df.drop(columns=['trust'])

# %%
partners_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1370 entries, 0 to 1630
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1370 non-null   int64
#  1   name            1370 non-null   object
#  2   street          1367 non-null   object
#  3   city            1346 non-null   object
#  4   zip             1347 non-null   object
#  5   country_id      1366 non-null   object
#  6   company_type    1370 non-null   object
#  7   credit          1370 non-null   float64
#  8   vat             1370 non-null   object
#  9   invoice_ids     1365 non-null   object
#  10  total_due       1370 non-null   float64
#  11  total_invoiced  1370 non-null   float64
#  12  total_overdue   1370 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 149.8+ KB

# %% [markdown]
# #### name and vat

# %%
partners_identification_df = partners_df[['name', 'vat']]

# %%
partners_identification_df[partners_identification_df['name'].str.contains('Hostinger')]
# Out:
#                                 name          vat
# 731  Hostinger International Limited    10301365E
# 732  Hostinger International Limited  CY10301365E

# %%
partners_df.to_pickle("partners_cleanedv2.pkl")

# %% [markdown]
# Un duplicado

# %%
partners_df = partners_df.drop(partners_df[partners_df['id'] == 731].index)

# %%
partners_df
# Out:
#          id                                name  \
# 0     14516                        200 Labs Inc
# 1     12500        202 Digital Reputation, S.L.
# 2     10577          2Be Confirmed Events, S.L.
# 3     12233             2BeGroup&Partners, S.L.
# 4     14539                2 Open EU CN, S.L.U.
# ...     ...                                 ...
# 1626  14891                       ZENVIA MEXICO
# 1627   9285  Zippy - Comercio e Distribuição SA
# 1628  11067                       Zoconet, S.L.
# 1629  14429                       Zumitow, S.L.
# 1630  14221                 Zure Barber Shop SL
#
#                                            street                    city  \
# 0                            490 Post St, Ste 526           San Francisco
# 1                         C/ Tuset 19, entresuelo               Barcelona
# 2                           C/ Doctor Fleming, 36                  Madrid
# 3               Rua Das Baleras, 13 - 4 Oficina 5  Santiago de Compostela
# 4                                    C/Sierpes, 3                 Cáceres
# ...                                           ...                     ...
# 1626          LAS PRADERAS 12 - PISO 1 CUBICULO A                Coyoacán
# 1627                    Rua João Mendonça, nº 529         Senhora da Hora
# 1628                 Avd. Juan López Peñalver, 17                  Málaga
# 1629  C/Pensamiento 27, Pta. 3, Esc. Izq.. Plt. 3                  Madrid
# 1630                 Calle Blas de Otero 16, Bajo                  Bilbao
#
#            zip            country_id company_type  credit           vat  \
# 0        94102  [233, United States]      company   0.000    46-4595829
# 1        08006           [68, Spain]      company   0.000     B06906226
# 2        28036           [68, Spain]      company   0.000     B86436243
# 3        15705           [68, Spain]      company   0.000     B70344619
# 4        10003           [68, Spain]      company   0.000     B10444545
# ...        ...                   ...          ...     ...           ...
# 1626     04500         [156, Mexico]      company   0.000  ZME201027JTA
# 1627  4464-503       [183, Portugal]      company   0.000   PT503226696
# 1628     29590           [68, Spain]      company   0.000     B29853264
# 1629     28020           [68, Spain]      company   0.000     B56156581
# 1630     48014           [68, Spain]      company   0.000     B01636679
#
#                                             invoice_ids  total_due  \
# 0     [196646, 196260, 197176, 196645, 196263, 19664...      0.000
# 1                      [101525, 100842, 100844, 100079]      0.000
# 2                                               [46745]      0.000
# 3                        [162545, 150132, 83140, 83139]      0.000
# 4                                      [166755, 166006]      0.000
# ...                                                 ...        ...
# 1626                           [185677, 185678, 185676]      0.000
# 1627                                     [13463, 11873]      0.000
# 1628                                            [58839]      0.000
# 1629                                   [160887, 155371]      0.000
# 1630                           [161640, 151998, 151947]      0.000
#
#       total_invoiced  total_overdue
# 0           1808.500          0.000
# 1            600.000          0.000
# 2            500.000          0.000
# 3           1871.900          0.000
# 4            600.000          0.000
# ...              ...            ...
# 1626        5264.020          0.000
# 1627        2650.000          0.000
# 1628          25.000          0.000
# 1629        1000.000          0.000
# 1630           9.910          0.000
#
# [1370 rows x 13 columns]

# %% [markdown]
# #### invoice_ids

# %%
all_invoices_df = pd.read_pickle("all_invoices.pkl")
all_invoices_df['move_type'].value_counts()
# Out:
# move_type
# entry          111574
# out_invoice     24293
# in_invoice      22930
# in_refund         541
# out_refund        467
# in_receipt         26
# Name: count, dtype: int64

# %%
original_partners_df = pd.read_pickle("partners.pkl")
invoice_sum = 0
for row in original_partners_df['invoice_ids']:
    if isinstance(row, list):
        invoice_sum += len(row)
    else:
        print(row)
print(f"Total invoices linked to partners: {invoice_sum}")
# Out:
# Total invoices linked to partners: 64298

# %%
invoice_sum = 0
for row in partners_df['invoice_ids']:
    if isinstance(row, list):
        invoice_sum += len(row)
    else:
        print(row)
print(f"Total invoices linked to partners: {invoice_sum}")
# Out:
# nan
# nan
# nan
# nan
# nan
# Total invoices linked to partners: 41435

# %% [markdown]
# Viendo que 64298 > 47223 (total de facturas out o in), entiendo que también tienen entrys en invoice_ids, por tanto, no me sirve, cogeré la lista final de facturas y lo haré manualmente

# %%
partners_df = pd.read_pickle("partners_cleanedv2.pkl")
invoices_df = pd.read_pickle("invoices_cleanedv7.pkl")
all_invoices_df = pd.read_pickle("all_invoices.pkl")

# %%
partners_df
# Out:
#          id                                name  \
# 0     14516                        200 Labs Inc
# 1     12500        202 Digital Reputation, S.L.
# 2     10577          2Be Confirmed Events, S.L.
# 3     12233             2BeGroup&Partners, S.L.
# 4     14539                2 Open EU CN, S.L.U.
# ...     ...                                 ...
# 1626  14891                       ZENVIA MEXICO
# 1627   9285  Zippy - Comercio e Distribuição SA
# 1628  11067                       Zoconet, S.L.
# 1629  14429                       Zumitow, S.L.
# 1630  14221                 Zure Barber Shop SL
#
#                                            street                    city  \
# 0                            490 Post St, Ste 526           San Francisco
# 1                         C/ Tuset 19, entresuelo               Barcelona
# 2                           C/ Doctor Fleming, 36                  Madrid
# 3               Rua Das Baleras, 13 - 4 Oficina 5  Santiago de Compostela
# 4                                    C/Sierpes, 3                 Cáceres
# ...                                           ...                     ...
# 1626          LAS PRADERAS 12 - PISO 1 CUBICULO A                Coyoacán
# 1627                    Rua João Mendonça, nº 529         Senhora da Hora
# 1628                 Avd. Juan López Peñalver, 17                  Málaga
# 1629  C/Pensamiento 27, Pta. 3, Esc. Izq.. Plt. 3                  Madrid
# 1630                 Calle Blas de Otero 16, Bajo                  Bilbao
#
#            zip            country_id company_type  credit           vat  \
# 0        94102  [233, United States]      company   0.000    46-4595829
# 1        08006           [68, Spain]      company   0.000     B06906226
# 2        28036           [68, Spain]      company   0.000     B86436243
# 3        15705           [68, Spain]      company   0.000     B70344619
# 4        10003           [68, Spain]      company   0.000     B10444545
# ...        ...                   ...          ...     ...           ...
# 1626     04500         [156, Mexico]      company   0.000  ZME201027JTA
# 1627  4464-503       [183, Portugal]      company   0.000   PT503226696
# 1628     29590           [68, Spain]      company   0.000     B29853264
# 1629     28020           [68, Spain]      company   0.000     B56156581
# 1630     48014           [68, Spain]      company   0.000     B01636679
#
#                                             invoice_ids  total_due  \
# 0     [196646, 196260, 197176, 196645, 196263, 19664...      0.000
# 1                      [101525, 100842, 100844, 100079]      0.000
# 2                                               [46745]      0.000
# 3                        [162545, 150132, 83140, 83139]      0.000
# 4                                      [166755, 166006]      0.000
# ...                                                 ...        ...
# 1626                           [185677, 185678, 185676]      0.000
# 1627                                     [13463, 11873]      0.000
# 1628                                            [58839]      0.000
# 1629                                   [160887, 155371]      0.000
# 1630                           [161640, 151998, 151947]      0.000
#
#       total_invoiced  total_overdue
# 0           1808.500          0.000
# 1            600.000          0.000
# 2            500.000          0.000
# 3           1871.900          0.000
# 4            600.000          0.000
# ...              ...            ...
# 1626        5264.020          0.000
# 1627        2650.000          0.000
# 1628          25.000          0.000
# 1629        1000.000          0.000
# 1630           9.910          0.000
#
# [1370 rows x 13 columns]

# %%
original_partners_df[original_partners_df['id'] == 15076]
# Out:
#          id               name  email  phone street   city    zip  \
# 1266  15076  pruebas-cif-12345  False  False  False  False  False
#
#           country_id  customer_rank  supplier_rank  ... credit_limit  \
# 1266  [251, Españaç]            190              0  ...        0.000
#
#       industry_id                vat  \
# 1266        False  PRuebas-cif-12345
#
#                                             invoice_ids  total_due  \
# 1266  [197554, 197553, 197552, 197551, 197548, 19754...      0.000
#
#       total_invoiced total_overdue   trust unpaid_invoice_ids  \
# 1266        2709.280         0.000  normal                 []
#
#       unpaid_invoices_count
# 1266                      0
#
# [1 rows x 25 columns]

# %% [markdown]
# Añado las facturas de cada cliente

# %%
partners_df["invoice_ids"] = [[] for _ in range(len(partners_df))]
not_found_partners = []
for invoice_id, partner_id in zip(invoices_df['id'], invoices_df['partner_id']):
    print(partner_id)
    if partners_df[partners_df['id'] == partner_id].empty:
        print(f"Partner ID {partner_id} not found in partners_df.")
        not_found_partners.append(partner_id)
        continue
    partners_df.loc[partners_df['id'] == partner_id, 'invoice_ids'].iloc[0].append(invoice_id)
# Out:
# 1
# 14913
# 1
# 1
# 8870
# 1
# 1
# 8527
# 1
# 1
# 1
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 15076
# Partner ID 15076 not found in partners_df.
# 123
# Partner ID 123 not found in partners_df.
# 123
# Partner ID 123 not found in partners_df.
# 15070
# Partner ID 15070 not found in partners_df.
# 8920
# 14945
# 14945
# 14945
# 14945
# 14945
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
#
# 1102   197237  FVT/2025/00683  out_invoice      not_paid           7
# 1103   197235  FVT/2025/00682  out_invoice      not_paid           7
# 1105   197233  FVT/2025/00680  out_invoice      not_paid           7
# 1134   197217            <NA>  out_invoice      not_paid           7
# 1164   197175   FACT-2025-XYZ  out_invoice      not_paid           7
# 1165   197174   FACT-2025-XYZ  out_invoice      not_paid           1
# 1166   197173   FACT-2025-XYZ  out_invoice      not_paid           1
# 2057   196186            <NA>  out_invoice      not_paid           3
# 2555   195207  FVC/2025/00005  out_invoice          paid           1
# 2556   195204  FVC/2025/00004  out_invoice          paid           1
# 2557   195208            <NA>  out_invoice      not_paid           7
# 2558   195203            <NA>  out_invoice      not_paid           1
# 2882   189531            <NA>  out_invoice      not_paid           3
# 3105   181418  INT/2025/00001  out_invoice      not_paid           8
# 3111   181419            <NA>  out_invoice      not_paid           8
# 3866   179523            <NA>  out_invoice      not_paid           8
# 5136   173716  FVE/2024/02968  out_invoice          paid           3
# 7120   166010  FVM/2024/00439  out_invoice          paid           6
# 11519  142728  FVM/2024/00327  out_invoice          paid           6
# 16806   84713  FVE/2023/02271  out_invoice      reversed           3
# 22088   41031  FVI/2023/00212  out_invoice          paid           2
# 22089   41030  FVI/2023/00211  out_invoice          paid           2
# 22468   30768  FVI/2023/00165  out_invoice          paid           2
# 22481   30755  FVI/2023/00152  out_invoice          paid           2
# 22510   27883  FVI/2023/00123  out_invoice          paid           2
#
#       partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 1102       10892            1         1.210            1.210   2025-07-29
# 1103       10892            1         1.210            1.210   2025-07-29
# 1105       10892            1         1.210            1.210   2025-07-29
# 1134       10892            1         1.000            1.000   2025-07-28
# 1164        <NA>            1         0.000            0.000         <NA>
# 1165        <NA>            1         0.000            0.000         <NA>
# 1166        <NA>            1         0.000            0.000         <NA>
# 2057        8996            1         0.000            0.000         <NA>
# 2555       13926            1         0.000            0.000   2025-03-26
# 2556          14            1         0.000            0.000   2025-03-26
# 2557       10892            1         0.000            0.000   2025-03-26
# 2558        8870            1         0.000            0.000   2025-03-25
# 2882        8679            1         0.000            0.000   2025-02-25
# 3105        <NA>           33         0.000            0.000         <NA>
# 3111        <NA>           33         0.000            0.000         <NA>
# 3866        <NA>           33         0.000            0.000         <NA>
# 5136        8299            1         0.970            0.000   2024-12-31
# 7120       12731            1         0.360            0.000   2024-11-30
# 11519      12731            1         0.150            0.000   2024-08-31
# 16806       8646            1         0.900            0.000   2023-12-31
# 22088       8901            1         1.200            0.000   2023-04-30
# 22089      10099            1         1.500            0.000   2023-04-30
# 22468       7623            1         1.390            0.000   2023-03-31
# 22481       9627            1         1.290            0.000   2023-03-31
# 22510       8837            1         1.030            0.000   2023-03-31
#
#       invoice_date_due payment_dates                            company_name  \
# 1102        2025-08-13          <NA>               Tandem Trade Marketing SL
# 1103        2025-08-13          <NA>               Tandem Trade Marketing SL
# 1105        2025-08-13          <NA>               Tandem Trade Marketing SL
# 1134        2025-08-12          <NA>               Tandem Trade Marketing SL
# 1164        2025-07-23          <NA>               Tandem Trade Marketing SL
# 1165        2025-07-23          <NA>      Grupo Viko Digital Marketing, S.A.
# 1166        2025-07-23          <NA>      Grupo Viko Digital Marketing, S.A.
# 2057        2025-05-09          <NA>                       Elogia Media S.L.
# 2555        2025-03-26          <NA>      Grupo Viko Digital Marketing, S.A.
# 2556        2025-03-26          <NA>      Grupo Viko Digital Marketing, S.A.
# 2557        2025-04-10          <NA>               Tandem Trade Marketing SL
# 2558        2025-03-25          <NA>      Grupo Viko Digital Marketing, S.A.
# 2882        2025-04-25          <NA>                       Elogia Media S.L.
# 3105        2025-02-03          <NA>         INICIATIVAS VIRTUALES DE MEXICO
# 3111        2025-02-03          <NA>         INICIATIVAS VIRTUALES DE MEXICO
# 3866        2025-01-22          <NA>         INICIATIVAS VIRTUALES DE MEXICO
# 5136        2025-03-01    06/03/2025                       Elogia Media S.L.
# 7120        2024-12-30    12/11/2024  Marketing4ecommerce Digital Content SL
# 11519       2024-09-30    13/08/2024  Marketing4ecommerce Digital Content SL
# 16806       2024-01-16          <NA>                       Elogia Media S.L.
# 22088       2023-05-30    15/06/2023          Ibrands Medios Interactivos SL
# 22089       2023-05-30    31/07/2023          Ibrands Medios Interactivos SL
# 22468       2023-04-30    04/05/2023          Ibrands Medios Interactivos SL
# 22481       2023-04-30    27/04/2023          Ibrands Medios Interactivos SL
# 22510       2023-04-30    02/05/2023          Ibrands Medios Interactivos SL
#
#                                       partner_name currency_name
# 1102                           Marketplaces España           EUR
# 1103                           Marketplaces España           EUR
# 1105                           Marketplaces España           EUR
# 1134                           Marketplaces España           EUR
# 1164                                          <NA>           EUR
# 1165                                          <NA>           EUR
# 1166                                          <NA>           EUR
# 2057           Aldi Masquefa Supermercados, S.L.U.           EUR
# 2555                           Marketplaces Italia           EUR
# 2556                     Tandem Trade Marketing SL           EUR
# 2557                           Marketplaces España           EUR
# 2558                                Hero España SA           EUR
# 2882          Fira Internacional de Barcelona (ES)           EUR
# 3105                                          <NA>           MXN
# 3111                                          <NA>           MXN
# 3866                                          <NA>           MXN
# 5136                   Madz Digital Business, S.L.           EUR
# 7120                                      Bitpanda           EUR
# 11519                                     Bitpanda           EUR
# 16806                                 DigiDum B.V.           EUR
# 22088                        New Lotus Web Limited           EUR
# 22089                          Naturalebio, S.R.L.           EUR
# 22468              Your Amazing Brand Amplifier SL           EUR
# 22481                       Marquise & Loren, S.L.           EUR
# 22510  Consumering Gestão de Marcas Unipessoal Lda           EUR

# %%
invoices_df['currency_name'].value_counts()
# Out:
# currency_name
# EUR    22405
# MXN     1628
# USD      243
# SEK        9
# COP        2
# GBP        1
# Name: count, dtype: int64

# %%
invoices_df.head()
# Out:
#        id                 name    move_type payment_state  company_id  \
# 0  198507  403-0199881-4444363  out_invoice      not_paid           7
# 1  198549       FVM/2025/00068  out_invoice      not_paid           6
# 2  198548                 <NA>  out_invoice      not_paid           6
# 3  198522       ES501155NOOJRS  out_invoice      not_paid           7
# 4  198516       ES501152NOOJRS  out_invoice      not_paid           7
#
#   partner_id  currency_id  amount_total  amount_residual invoice_date  \
# 0          1            1         43.56            43.56   2025-11-10
# 1      14913            1        121.00           121.00   2025-11-07
# 2      14913            1        726.00           726.00         <NA>
# 3          1            1        116.16           116.16   2025-11-06
# 4          1            1         43.56            43.56   2025-11-06
#
#   invoice_date_due payment_dates                            company_name  \
# 0       2025-11-06          <NA>               Tandem Trade Marketing SL
# 1       2025-12-07          <NA>  Marketing4ecommerce Digital Content SL
# 2       2025-12-07          <NA>  Marketing4ecommerce Digital Content SL
# 3       2025-11-06          <NA>               Tandem Trade Marketing SL
# 4       2025-11-06          <NA>               Tandem Trade Marketing SL
#
#                          partner_name currency_name
# 0  Grupo Viko Digital Marketing, S.A.           EUR
# 1                     Ser Sport, S.L.           EUR
# 2                     Ser Sport, S.L.           EUR
# 3  Grupo Viko Digital Marketing, S.A.           EUR
# 4  Grupo Viko Digital Marketing, S.A.           EUR

# %% [markdown]
# No parece que hayan muchos campos con valores null:
# - **payment_dates**: principalmente de facturas impagadas
# - **invoice_date**: algunas facturas sin fecha
# - **payment_ids**: no hay ningún dato útil

# %%
differences = invoices_df[invoices_df['invoice_date'] != invoices_df['date']]
differences.tail(3)
# Out:
#           id             name    move_type payment_state  \
# 24263  13080  INV1/2022/00002  out_invoice          paid
# 24269  13244  INV1/2022/00001  out_invoice      reversed
# 24270  13079  INV1/2022/00001  out_invoice      reversed
#
#                                  company_id                      partner_id  \
# 24263  [8, INICIATIVAS VIRTUALES DE MEXICO]      [8961, ODEM INTERNACIONAL]
# 24269      [9, MITTUM MARKETING RELACIONAL]  [8994, Pagos y Servicios S.A.]
# 24270  [8, INICIATIVAS VIRTUALES DE MEXICO]               [9392, AXEL DEMB]
#
#       currency_id  amount_total  amount_paid  amount_residual invoice_date  \
# 24263   [33, MXN]      95120.00          0.0              0.0   2022-12-21
# 24269    [2, USD]       5411.25          0.0              0.0   2022-12-30
# 24270   [33, MXN]        800.00          0.0              0.0   2022-12-29
#
#       invoice_date_due payment_dates       date         create_date  \
# 24263       2023-02-19    2023-02-14 2022-12-31 2023-01-27 13:52:02
# 24269       2023-01-29           NaT 2022-12-31 2023-01-27 14:38:02
# 24270       2023-02-15           NaT 2022-12-31 2023-01-27 13:52:02
#
#        payment_id payment_ids  days_late
# 24263       False          []       -5.0
# 24269       False          []        NaN
# 24270       False          []        NaN

# %% [markdown]
# No son iguales

# %%
n_nulls = invoices_df['payment_dates'].isnull().sum()
n_not_paid = (invoices_df['is_paid'] == False).sum()
print(f"Nulls: {n_nulls} / Not paid: {n_not_paid}")
# Out:
# Nulls: 5350 / Not paid: 5357

# %%
not_null_and_not_paid = invoices_df[invoices_df['payment_dates'].notnull() & (invoices_df['is_paid'] == False)]
not_null_and_not_paid['payment_state'].value_counts()
# Out:
# payment_state
# in_payment    139
# partial        12
# Name: count, dtype: int64

# %%
null_and_paid = invoices_df[invoices_df['payment_dates'].notnull() & (invoices_df['is_paid'] == False)]
not_null_and_not_paid

# %% [markdown]
# Convierto fechas y creo columna de días de pago tarde:

# %%
invoices_df['invoice_date_due'] = pd.to_datetime(invoices_df['invoice_date_due'], errors='coerce', format='%Y-%m-%d')
invoices_df['invoice_date'] = pd.to_datetime(invoices_df['invoice_date'], errors='coerce')
invoices_df['payment_dates'] = pd.to_datetime(invoices_df['payment_dates'], errors='coerce', format='%d/%m/%Y')
invoices_df['date'] = pd.to_datetime(invoices_df['date'], errors='coerce', format='%Y-%m-%d')
invoices_df['create_date'] = pd.to_datetime(invoices_df['create_date'], errors='coerce')
invoices_df['days_late'] = (invoices_df['payment_dates'] - invoices_df['invoice_date_due']).dt.days
invoices_df['is_paid'] = invoices_df['payment_state'] == "paid"

# %% [markdown]
# Selecciono los campos relevantes para el análisis:

# %%
numerical_cols = invoices_df.select_dtypes(include=['number']).columns.tolist()
categorical_cols = invoices_df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()
date_cols = invoices_df.select_dtypes(include=['datetime64']).columns.tolist()

# %%
print(f"Tipo fecha: {date_cols}")
print(f"Categóricas: {categorical_cols}")
print(f"Numéricas: {numerical_cols}")
# Out:
# Tipo fecha: ['invoice_date', 'invoice_date_due', 'payment_dates', 'date', 'create_date']
# Categóricas: ['name', 'move_type', 'payment_state', 'company_id', 'partner_id', 'currency_id', 'payment_id', 'payment_ids']
# Numéricas: ['id', 'amount_total', 'amount_paid', 'amount_residual', 'days_late']

# %% [markdown]
# Separo por empresa:

# %%
invoices_by_company = {}
for c in company_ids:
    invoices_by_company[c] = invoices_df[invoices_df['company_id'].str[0] == c]

# %% [markdown]
# Grupo Viko Digital Marketing, S.A. (1)

# %%
invoices_by_company[1]
# Out:
#            id             name    move_type payment_state  \
# 1165   197174    FACT-2025-XYZ  out_invoice      not_paid
# 1166   197173    FACT-2025-XYZ  out_invoice      not_paid
# 1167   197172    FACT-2025-XYZ  out_invoice      not_paid
# 1168   197171    FACT-2025-XYZ  out_invoice      not_paid
# 1765   196522   FVV/2025/00001  out_invoice      not_paid
# ...       ...              ...          ...           ...
# 24246   12479  INV1/2022/00005  out_invoice      reversed
# 24252   12478  INV1/2022/00004  out_invoice          paid
# 24258   12477  INV1/2022/00003  out_invoice          paid
# 24264   12476  INV1/2022/00002  out_invoice          paid
# 24271   12475  INV1/2022/00001  out_invoice          paid
#
#                                     company_id  \
# 1165   [1, Grupo Viko Digital Marketing, S.A.]
# 1166   [1, Grupo Viko Digital Marketing, S.A.]
# 1167   [1, Grupo Viko Digital Marketing, S.A.]
# 1168   [1, Grupo Viko Digital Marketing, S.A.]
# 1765   [1, Grupo Viko Digital Marketing, S.A.]
# ...                                        ...
# 24246  [1, Grupo Viko Digital Marketing, S.A.]
# 24252  [1, Grupo Viko Digital Marketing, S.A.]
# 24258  [1, Grupo Viko Digital Marketing, S.A.]
# 24264  [1, Grupo Viko Digital Marketing, S.A.]
# 24271  [1, Grupo Viko Digital Marketing, S.A.]
#
#                                        partner_id currency_id  amount_total  \
# 1165                                        False    [1, EUR]          0.00
# 1166                                        False    [1, EUR]          0.00
# 1167                 [123, María Sieiro Alfonsin]    [1, EUR]        484.00
# 1168                 [123, María Sieiro Alfonsin]    [1, EUR]        484.00
# 1765               [8571, Google Ireland Limited]    [1, EUR]         10.00
# ...                                           ...         ...           ...
# 24246       [15, INICIATIVAS VIRTUALES DE MEXICO]    [1, EUR]       2122.40
# 24252  [7749, Property Technology Services, S.L.]    [1, EUR]        544.50
# 24258                    [9250, Equipzilla, S.L.]    [1, EUR]        181.50
# 24264        [8048, Lanai Capital Partners, S.L.]    [1, EUR]        145.03
# 24271                [12, Kraz Data Solutions SL]    [1, EUR]      24200.00
#
#        amount_paid  amount_residual invoice_date invoice_date_due  \
# 1165           0.0              0.0        False       2025-07-23
# 1166           0.0              0.0        False       2025-07-23
# 1167           0.0            484.0   2025-07-23       2025-07-23
# 1168           0.0            484.0   2025-07-23       2025-07-23
# 1765           0.0             10.0        False       2025-06-05
# ...            ...              ...          ...              ...
# 24246          0.0              0.0   2022-11-30       2023-01-29
# 24252          0.0              0.0   2022-12-31       2023-01-22
# 24258          0.0              0.0   2022-12-31       2023-01-22
# 24264          0.0              0.0   2022-12-31       2023-01-30
# 24271          0.0              0.0   2022-12-31       2023-02-14
#
#       payment_dates        date          create_date  payment_id payment_ids  \
# 1165            NaT  2025-07-23  2025-07-23 08:54:56       False          []
# 1166            NaT  2025-07-23  2025-07-23 08:54:47       False          []
# 1167            NaT  2025-07-23  2025-07-23 08:50:42       False          []
# 1168            NaT  2025-07-23  2025-07-23 08:50:04       False          []
# 1765            NaT  2025-06-05  2025-06-05 13:56:40       False          []
# ...             ...         ...                  ...         ...         ...
# 24246           NaT  2022-12-31  2023-01-26 15:29:31       False          []
# 24252    2023-01-25  2022-12-31  2023-01-26 15:29:31       False          []
# 24258    2023-01-13  2022-12-31  2023-01-26 15:29:31       False          []
# 24264    2023-06-06  2022-12-31  2023-01-26 15:29:31       False          []
# 24271           NaT  2022-12-31  2023-01-26 15:29:31       False          []
#
#        company_id_id  partner_id_id  days_late
# 1165               1            NaN        NaN
# 1166               1            NaN        NaN
# 1167               1          123.0        NaN
# 1168               1          123.0        NaN
# 1765               1         8571.0        NaN
# ...              ...            ...        ...
# 24246              1           15.0        NaN
# 24252              1         7749.0        3.0
# 24258              1         9250.0       -9.0
# 24264              1         8048.0      127.0
# 24271              1           12.0        NaN
#
# [140 rows x 20 columns]

# %% [markdown]
# Elogia Media S.L. (3)

# %% [markdown]
# Ibrands Medios Interactivos SL (2)

# %% [markdown]
# Kraz Data Solutions SL (5)

# %% [markdown]
# Marketing4ecommerce Digital Content SL (6)

# %% [markdown]
# Octoplus Digital Shelf Optimization SL (13)

# %% [markdown]
# Tandem Trade Marketing SL (7)

# %% [markdown]
# DigitalPla2021, S.L. (11)

# %% [markdown]
# Ideas y Estrategia Digital SL (14)

# %% [markdown]
# INICIATIVAS VIRTUALES DE MEXICO	(8)

# %% [markdown]
# IBRANDS MEDIOS INTERACTIVOS DE MEXICO (12)

# %% [markdown]
# Creo dos columnas nuevas con únicamente el id de la empresa y del partner en la factura

# %% [markdown]
# Filtro las facturas por empresa:

# %%
partners_df['id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 partners_df['id']
#
# NameError: name 'partners_df' is not defined

# %%
invoices_df['company_id'].value_counts()
# Out:
# company_id
# [7, Tandem Trade Marketing SL]                  12429
# [3, Elogia Media S.L.]                           6348
# [8, INICIATIVAS VIRTUALES DE MEXICO]             1617
# [6, Marketing4ecommerce Digital Content SL]      1184
# [11, DigitalPla2021, S.L.]                        785
# [2, Ibrands Medios Interactivos SL]               724
# [14, Ideas y Estrategia Digital SL]               595
# [13, Octoplus Digital Shelf Optimization SL]      194
# [1, Grupo Viko Digital Marketing, S.A.]           140
# [9, MITTUM MARKETING RELACIONAL]                  115
# [5, Kraz Data Solutions SL]                       114
# [12, IBRANDS MEDIOS INTERACTIVOS DE MEXICO]        43
# Name: count, dtype: int64

# %% [markdown]
# #### 1.2.2. res.partner

# %%
partners_df = pd.DataFrame(asyncio.run(data_retriever.get_all_customer_partners()))
# Out:
# Recuperadas 500 facturas, total: 500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1631 non-null   int64
#  1   name                   1631 non-null   object
#  2   email                  1631 non-null   object
#  3   phone                  1631 non-null   object
#  4   street                 1631 non-null   object
#  5   city                   1631 non-null   object
#  6   zip                    1631 non-null   object
#  7   country_id             1631 non-null   object
#  8   customer_rank          1631 non-null   int64
#  9   supplier_rank          1631 non-null   int64
#  10  category_id            1631 non-null   object
#  11  is_company             1631 non-null   bool
#  12  company_type           1631 non-null   object
#  13  company_id             1631 non-null   object
#  14  credit                 1631 non-null   float64
#  15  credit_limit           1631 non-null   float64
#  16  debit                  1631 non-null   float64
#  17  debit_limit            1631 non-null   float64
#  18  industry_id            1631 non-null   object
#  19  invoice_ids            1631 non-null   object
#  20  total_due              1631 non-null   float64
#  21  total_invoiced         1631 non-null   float64
#  22  total_overdue          1631 non-null   float64
#  23  trust                  1631 non-null   object
#  24  unpaid_invoice_ids     1631 non-null   object
#  25  unpaid_invoices_count  1631 non-null   int64
# dtypes: bool(1), float64(7), int64(4), object(14)
# memory usage: 320.3+ KB

# %%
partners_df_original = partners_df.copy()

# %%
partners_df = partners_df_original.copy()

# %%
invoices_df_original.dtypes
# Out:
# id                    int64
# name                 object
# move_type            object
# payment_state        object
# company_id           object
# partner_id           object
# currency_id          object
# amount_total        float64
# amount_paid         float64
# amount_residual     float64
# invoice_date         object
# invoice_date_due     object
# payment_dates        object
# date                 object
# create_date          object
# payment_id             bool
# payment_ids          object
# dtype: object

# %%
object_cols = partners_df.select_dtypes(include='object').columns
partners_df[object_cols] = (partners_df[object_cols].replace({False: pd.NA}))

# %%
partners_df[object_cols] = partners_df[object_cols].map(lambda x: np.nan if x == [] else x)

# %%
partners_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1631 non-null   int64
#  1   name                   1630 non-null   object
#  2   email                  281 non-null    object
#  3   phone                  12 non-null     object
#  4   street                 1568 non-null   object
#  5   city                   1549 non-null   object
#  6   zip                    1551 non-null   object
#  7   country_id             1616 non-null   object
#  8   customer_rank          1631 non-null   int64
#  9   supplier_rank          1631 non-null   int64
#  10  category_id            284 non-null    object
#  11  is_company             1631 non-null   bool
#  12  company_type           1631 non-null   object
#  13  company_id             569 non-null    object
#  14  credit                 1631 non-null   float64
#  15  credit_limit           1631 non-null   float64
#  16  debit                  1631 non-null   float64
#  17  debit_limit            1631 non-null   float64
#  18  industry_id            1 non-null      object
#  19  invoice_ids            1551 non-null   object
#  20  total_due              1631 non-null   float64
#  21  total_invoiced         1631 non-null   float64
#  22  total_overdue          1631 non-null   float64
#  23  trust                  1631 non-null   object
#  24  unpaid_invoice_ids     128 non-null    object
#  25  unpaid_invoices_count  1631 non-null   int64
# dtypes: bool(1), float64(7), int64(4), object(14)
# memory usage: 320.3+ KB

# %%
partners_df[partners_df['is_company'] == False]
# Out:
#          id                    name                              email phone  \
# 8     10970           Aaron Escobar            esaaroleesco@icloud.com  <NA>
# 12    12023          Abel Hernández  abel@congresomarketingdigital.com  <NA>
# 15     9405             Facturacion              facturacion@aby.group  <NA>
# 20    10178           Luís Granados               lgranados@acesur.com  <NA>
# 34    13148                 Invoice                   invoice@adock.io  <NA>
# ...     ...                     ...                                ...   ...
# 1568  13665                  Teresa                 teresa@growwer.com  <NA>
# 1569  13577  Vitola Marketing, S.L.                               <NA>  <NA>
# 1580  13664          Celeste Romero             celeste.arias@vtex.com  <NA>
# 1604  13788          Sebastián Díaz              sebastiandiaz@wix.com  <NA>
# 1616  10138       Yariendy Sandoval              yari_0307@hotmail.com  <NA>
#
#                                          street                     city  \
# 8                                Cuauhtemoc 123         Ciudad de México
# 12                           Caldas Da Raihna 6                  Badajoz
# 15                     Hijas de la Caridad, 108                   Bilbao
# 20                     Carretera de la carolina                  Vilches
# 34              Calle Cardenal Vives i Tutó, 65                Barcelona
# ...                                         ...                      ...
# 1568  Carretera d'Esplugues 47, Esc. D, 5 - 1    Cornellà  del Llobregat
# 1569                                       <NA>                     <NA>
# 1580      WeWork Aviation House, 125 Kingsway                     London
# 1604             40 Hanamal Tel Aviv, Beit Yoel                 Tel Aviv
# 1616                             Calle 3n 2e-53                   Cucuta
#
#            zip             country_id  customer_rank  supplier_rank  ...  \
# 8        16090          [156, Mexico]              2              0  ...
# 12        6011            [68, Spain]              1              0  ...
# 15       48009            [68, Spain]              2              0  ...
# 20       23220            [68, Spain]              1              0  ...
# 34       08034            [68, Spain]              1              0  ...
# ...        ...                    ...            ...            ...  ...
# 1568     08940            [68, Spain]              1              0  ...
# 1569      <NA>                   <NA>              2              0  ...
# 1580  WC2B 6NH  [231, United Kingdom]              1              0  ...
# 1604   6350671          [102, Israel]              1              0  ...
# 1616    540001         [49, Colombia]              2              0  ...
#
#      debit  debit_limit industry_id            invoice_ids  total_due  \
# 8      0.0          0.0        <NA>  [63361, 63691, 55911]        0.0
# 12     0.0          0.0        <NA>         [77026, 93888]        0.0
# 15     0.0          0.0        <NA>                    NaN        0.0
# 20     0.0          0.0        <NA>                    NaN        0.0
# 34     0.0          0.0        <NA>                    NaN        0.0
# ...    ...          ...         ...                    ...        ...
# 1568   0.0          0.0        <NA>                    NaN        0.0
# 1569   0.0          0.0        <NA>                    NaN        0.0
# 1580   0.0          0.0        <NA>                    NaN        0.0
# 1604   0.0          0.0        <NA>                    NaN        0.0
# 1616   0.0          0.0        <NA>         [44941, 31910]        0.0
#
#       total_invoiced  total_overdue   trust unpaid_invoice_ids  \
# 8              39.98            0.0  normal                NaN
# 12            199.00            0.0  normal                NaN
# 15              0.00            0.0  normal                NaN
# 20              0.00            0.0  normal                NaN
# 34              0.00            0.0  normal                NaN
# ...              ...            ...     ...                ...
# 1568            0.00            0.0  normal                NaN
# 1569            0.00            0.0  normal                NaN
# 1580            0.00            0.0  normal                NaN
# 1604            0.00            0.0  normal                NaN
# 1616           78.00            0.0  normal                NaN
#
#      unpaid_invoices_count
# 8                        0
# 12                       0
# 15                       0
# 20                       0
# 34                       0
# ...                    ...
# 1568                     0
# 1569                     0
# 1580                     0
# 1604                     0
# 1616                     0
#
# [261 rows x 26 columns]

# %%
partners_df
# Out:
#          id                                name email phone  \
# 0     14516                        200 Labs Inc  <NA>  <NA>
# 1     12500        202 Digital Reputation, S.L.  <NA>  <NA>
# 2     10577          2Be Confirmed Events, S.L.  <NA>  <NA>
# 3     12233             2BeGroup&Partners, S.L.  <NA>  <NA>
# 4     14539                2 Open EU CN, S.L.U.  <NA>  <NA>
# ...     ...                                 ...   ...   ...
# 1626  14891                       ZENVIA MEXICO  <NA>  <NA>
# 1627   9285  Zippy - Comercio e Distribuição SA  <NA>  <NA>
# 1628  11067                       Zoconet, S.L.  <NA>  <NA>
# 1629  14429                       Zumitow, S.L.  <NA>  <NA>
# 1630  14221                 Zure Barber Shop SL  <NA>  <NA>
#
#                                            street                    city  \
# 0                            490 Post St, Ste 526           San Francisco
# 1                         C/ Tuset 19, entresuelo               Barcelona
# 2                           C/ Doctor Fleming, 36                  Madrid
# 3               Rua Das Baleras, 13 - 4 Oficina 5  Santiago de Compostela
# 4                                    C/Sierpes, 3                 Cáceres
# ...                                           ...                     ...
# 1626          LAS PRADERAS 12 - PISO 1 CUBICULO A                Coyoacán
# 1627                    Rua João Mendonça, nº 529         Senhora da Hora
# 1628                 Avd. Juan López Peñalver, 17                  Málaga
# 1629  C/Pensamiento 27, Pta. 3, Esc. Izq.. Plt. 3                  Madrid
# 1630                 Calle Blas de Otero 16, Bajo                  Bilbao
#
#            zip            country_id  customer_rank  supplier_rank  ...  \
# 0        94102  [233, United States]              1              5  ...
# 1        08006           [68, Spain]              3              0  ...
# 2        28036           [68, Spain]              1              0  ...
# 3        15705           [68, Spain]              3              0  ...
# 4        10003           [68, Spain]              1              0  ...
# ...        ...                   ...            ...            ...  ...
# 1626     04500         [156, Mexico]              1              0  ...
# 1627  4464-503       [183, Portugal]              1              0  ...
# 1628     29590           [68, Spain]              1              0  ...
# 1629     28020           [68, Spain]              1              0  ...
# 1630     48014           [68, Spain]              3              0  ...
#
#       debit  debit_limit industry_id  \
# 0     600.0          0.0        <NA>
# 1       0.0          0.0        <NA>
# 2       0.0          0.0        <NA>
# 3       0.0          0.0        <NA>
# 4       0.0          0.0        <NA>
# ...     ...          ...         ...
# 1626    0.0          0.0        <NA>
# 1627    0.0          0.0        <NA>
# 1628    0.0          0.0        <NA>
# 1629    0.0          0.0        <NA>
# 1630    0.0          0.0        <NA>
#
#                                             invoice_ids  total_due  \
# 0     [196646, 196260, 197176, 196645, 196263, 19664...        0.0
# 1                      [101525, 100842, 100844, 100079]        0.0
# 2                                               [46745]        0.0
# 3                        [162545, 150132, 83140, 83139]        0.0
# 4                                      [166755, 166006]        0.0
# ...                                                 ...        ...
# 1626                           [185677, 185678, 185676]        0.0
# 1627                                     [13463, 11873]        0.0
# 1628                                            [58839]        0.0
# 1629                                   [160887, 155371]        0.0
# 1630                           [161640, 151998, 151947]        0.0
#
#       total_invoiced  total_overdue   trust unpaid_invoice_ids  \
# 0            1808.50            0.0  normal                NaN
# 1             600.00            0.0  normal                NaN
# 2             500.00            0.0  normal                NaN
# 3            1871.90            0.0  normal                NaN
# 4             600.00            0.0  normal                NaN
# ...              ...            ...     ...                ...
# 1626         5264.02            0.0  normal                NaN
# 1627         2650.00            0.0  normal                NaN
# 1628           25.00            0.0  normal                NaN
# 1629         1000.00            0.0  normal                NaN
# 1630            9.91            0.0  normal                NaN
#
#      unpaid_invoices_count
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 1626                     0
# 1627                     0
# 1628                     0
# 1629                     0
# 1630                     0
#
# [1631 rows x 26 columns]

# %% [markdown]
# A simple vista, se puede observar que hay muchos valores vacíos (False en Odoo) y campos vacíos ([] en category_id).

# %% [markdown]
# Analizaré los clientes de cada empresa:

# %%
partners_df['company_id'].value_counts()
# Out:
# company_id
# False                                           1062
# [7, Tandem Trade Marketing SL]                   179
# [11, DigitalPla2021, S.L.]                       154
# [8, INICIATIVAS VIRTUALES DE MEXICO]             153
# [6, Marketing4ecommerce Digital Content SL]       29
# [14, Ideas y Estrategia Digital SL]               18
# [3, Elogia Media S.L.]                            17
# [12, IBRANDS MEDIOS INTERACTIVOS DE MEXICO]        6
# [13, Octoplus Digital Shelf Optimization SL]       6
# [9, MITTUM MARKETING RELACIONAL]                   4
# [2, Ibrands Medios Interactivos SL]                3
# Name: count, dtype: int64

# %% [markdown]
# La mayoría de partners no tienen asociadas las empresas con las que han hecho transacciones...
#
# Lo sacaré de account.move

# %%
company_ids = [1,2,3,5,6,7,8,9,11,12,13,14]
def get_partners_by_company(company_id):
    invoices_id = invoices_df[invoices_df['company_id_id'] == 1]
    partners_id = invoices_id['partner_id_id'].unique()
    return partners_df[partners_df['id'].isin(partners_id)]

# %%
partners_by_company = []
for c in company_ids:
    partners_by_company.append({c : get_partners_by_company(c)})

# %%
invoices_df['company_id_id'] = invoices_df['company_id'].str[0]
invoices_df['partner_id_id'] = invoices_df['partner_id'].str[0]

# %%
company_ids = [1,2,3,5,6,7,8,9,11,12,13,14]
invoices_by_company = {}
for c in company_ids:
    invoices_by_company[c] = invoices_df[invoices_df['company_id'].str[0] == c]

# %% [markdown]
# Grupo Viko Digital Marketing, S.A. (1)

# %%
invoices_by_company[1]['partner_id'].value_counts()
# [8895, Datawork Marketing SL]                 1
# [7481, Prosegur Compañía de Seguridad SA]     1
# [7519, Roman y Asociados S.A.]                1
# [9309, Diario ABC, S.L.]                      1
# Name: count, Length: 96, dtype: int64

# %% [markdown]
# Kraz Data Solutions SL (5)

# %%
invoices_by_company[5]['partner_id'].value_counts()
# Out:
# partner_id
# [10, Elogia Media S.L.]                                       16
# [7812, Salvetti & Llombart, S.L.]                              9
# [7773, Kave Home S.L.]                                         8
# [7485, Unilever España, S.A.]                                  8
# [1, Grupo Viko Digital Marketing, S.A.]                        7
# [7419, Editorial Planeta, S.A.U.]                              7
# [7461, Joyeria Tous S.A]                                       7
# [7479, Vinoselección, S.A.]                                    6
# [12541, SEAT, S.A.]                                            6
# [10993, Pikostore, S.L.U.]                                     5
# [10994, Pikolinos Intercontinental, S.A.]                      5
# [8679, Fira Internacional de Barcelona (ES)]                   4
# [10436, Octoplus Digital Shelf Optimization SL]                4
# [13766, RuralMed, S.L.]                                        3
# [7409, Ferrer Internacional, S.A.]                             3
# [7421, Saba Aparcamientos S.A.]                                2
# [16, MITTUM MARKETING RELACIONAL]                              2
# [13559, Kern Pharma S.L.]                                      2
# [12695, Nocturna Therapeutics, S.L.]                           2
# [12776, Corporació Catalana de Mitjans Audiovisuals, S.A.]     2
# [14175, Planeta Innovación, S.A.]                              2
# [8575, Meta Platforms Ireland Limited]                         1
# [14176, Grupo J. Uriach, S.L.]                                 1
# [15, INICIATIVAS VIRTUALES DE MEXICO]                          1
# [13780, The GB Foods Africa, S.L.U.]                           1
# Name: count, dtype: int64

# %% [markdown]
# Marketing4ecommerce Digital Content SL (6)

# %%
invoices_by_company[6]['partner_id'].value_counts()
# Out:
# partner_id
# [8571, Google Ireland Limited]            39
# [9277, Pipedrive Inc]                     25
# [8012, Virality Media, S.L.]              23
# [9665, Pixel Labs LLC]                    22
# [9605, Getlinko International, S.L.]      21
#                                           ..
# [14923, Ceramic Connection Shop, S.L.]     1
# [14912, Santafixie Group, S.L.]            1
# [14911, Channelbook, S.L.U.]               1
# [15057, Flyeralarm, S.L.]                  1
# [8527, Fundació Pasqual Maragall]          1
# Name: count, Length: 472, dtype: int64

# %% [markdown]
# Octoplus Digital Shelf Optimization SL (13)

# %%
invoices_by_company[13]['partner_id'].value_counts()
# Out:
# partner_id
# [10590, Beam Suntory Distribution SL]                    98
# [10587, Beam Inc. Global Business Services]              62
# [7403, Nestlé España S.A.]                                5
# [10598, Medios Activos y Aplicacion de Servicios S.L]     4
# [10595, Ceva Sante Animale]                               4
# [12060, Beam Suntory España Beverages, S.L.U.]            3
# [10616, Beautyge, S.L.]                                   3
# [8062, Optopus Optimisation, S.L.]                        2
# [14768, Beam Suntory Asia Pte. Ltd.]                      2
# [10858, Beam Canada Inc.]                                 2
# [14722, Colgate-Palmolive España, S.A.]                   2
# [10594, Beam Suntory Australia Pty Ltd]                   2
# [13260, Ideas y Estrategia Digital SL]                    1
# [10592, Beam Suntory Germany GmbH]                        1
# [11484, Casa Santiveri, S.L.]                             1
# [10589, Beam Suntory Spain S.L]                           1
# [10588, Cuetara S.L.U]                                    1
# Name: count, dtype: int64

# %% [markdown]
# Tandem Trade Marketing SL (7)

# %%
invoices_by_company[7]['partner_id'].value_counts()
# Out:
# partner_id
# [10892, Marketplaces España]                 7606
# [13926, Marketplaces Italia]                 2742
# [13924, Marketplaces Francia]                 499
# [14, Tandem Trade Marketing SL]               326
# [15076, pruebas-cif-12345]                    190
#                                              ...
# [10087, José Carlos Rodríguez Diago]            1
# [10331, Inmopanta. S.L.]                        1
# [10332, TecniOrganic, S.L.U.]                   1
# [10333, La Costanera Santa Eulalia, S.L.]       1
# [15041, Nicolás Sánchez-Biezma]                 1
# Name: count, Length: 296, dtype: int64

# %% [markdown]
# DigitalPla2021, S.L. (11)

# %%
invoices_by_company[11]['partner_id'].value_counts()
# Out:
# partner_id
# [9902, Manuel Alejandro Mesa Sánchez]    52
# [9913, Sara Carbajo]                     26
# [9881, Betty Lepina]                     26
# [9916, Tomasz Smardzewski]               26
# [9901, Paula Garcia Bustos]              26
#                                          ..
# [9887, Lola Garau]                        1
# [9896, ISABEL ORGAZ TARAVILLA]            1
# [9886, Daniel Lopez]                      1
# [9883, Carmen Luz Zarrías Villena]        1
# [9917, Valentin Salas]                    1
# Name: count, Length: 233, dtype: int64

# %% [markdown]
# Ideas y Estrategia Digital SL (14)

# %%
invoices_by_company[14]['partner_id'].value_counts()
# Out:
# partner_id
# [13557, Chiesi España, S.A]                          124
# [13548, Esteve Pharmaceuticals SA]                   113
# [13558, Elanco Spain S.L.]                           106
# [8933, Zambon, S.A.U.]                                66
# [13559, Kern Pharma S.L.]                             47
# [13549, Swedish Orphan Biovitrum S.L.]                34
# [13542, Laboratorio Reig Jofre, S.A.]                 21
# [13547, Alexion Pharma Nordics AB]                    18
# [13543, Alexion Pharma GMBH]                          11
# [14595, Swedish Orphan Biovitrum AB (publ)]            8
# [7583, Reckitt Benckiser Healthcare, S.A.]             8
# [14476, Faes Farma S.A.]                               7
# [13654, Atika Pharma S.L.]                             7
# [13545, Elanco AH Portugal Unipessoal Lda.]            6
# [13544, Angelini Pharma Portugal, Unipessoal Lda]      3
# [13553, AdSalutem Lullaai S.L]                         2
# [14627, Asociación Española Contra el Cáncer]          2
# [10, Elogia Media S.L.]                                2
# [14319, Neuraxpharm Spain s.l.u.]                      2
# [14921, Alexion Pharma Austria GmbH]                   1
# [14482, BRAEBURN WHISKY SPAIN, S.L.U]                  1
# [13889, Ophtalmic World Leaders]                       1
# [13939, Josep Soldevila Melgarejo]                     1
# [13684, Angelini Pharma España, S.L.U]                 1
# [13551, Swedish Orphan Biovitrum Unipessoal LDA]       1
# [13550, Laboratorios Vilardell S.A.]                   1
# [13552, Astellas Pharma S.A.]                          1
# Name: count, dtype: int64

# %% [markdown]
# INICIATIVAS VIRTUALES DE MEXICO	(8)

# %%
invoices_by_company[8]['partner_id'].value_counts()
# Out:
# partner_id
# [12056, COMERCIALIZADORA ALMACENES GARCIA DE MEXICO]    69
# [9678, DAWN-MIXCO INTERNACIONAL]                        66
# [8960, SEPHORA MEXICO]                                  60
# [11041, TOYOTA TSUSHO CORPORATION DE MEXICO]            47
# [9759, VCD CONSTRUCCION Y DESARROLLO]                   44
#                                                         ..
# [9391, RAGS]                                             1
# [9390, SERVICIOS DE CAPITAL HUMANO AXO]                  1
# [9389, MR BON MEXICO]                                    1
# [9388, PULQUEDIGITAL]                                    1
# [9392, AXEL DEMB]                                        1
# Name: count, Length: 172, dtype: int64

# %% [markdown]
# IBRANDS MEDIOS INTERACTIVOS DE MEXICO (12)

# %%
invoices_by_company[12]['partner_id'].value_counts()
# Out:
# partner_id
# [8987, ASALES, SERVICIOS DE MARKETING EN INTERNET]    30
# [9387, TIENDAS SORIANA]                                5
# [11708, ANTEVENIO MEXICO]                              4
# [13917, KOVAFINANSI AMERICAS CORPORATE]                1
# [16, MITTUM MARKETING RELACIONAL]                      1
# [9427, SILVERSPRINGS SERVICIOS CORPORATIVOS]           1
# [9386, INDUSTRIAS TUK]                                 1
# Name: count, dtype: int64

# %% [markdown]
# MITTUM MARKETING RELACIONAL (9)

# %%
invoices_by_company[9]['partner_id'].value_counts()
# Out:
# partner_id
# [8991, SEGUROS BANAMEX]                           30
# [8989, TARJETAS BANAMEX]                          28
# [8993, BANCO NACIONAL DE MEXICO]                  26
# [9797, SOCIEDAD COOPERATIVA DE CONSUMO PEMEX,]    20
# [8994, Pagos y Servicios S.A.]                     6
# [8992, EVO PAYMENTS MEXICO.]                       5
# Name: count, dtype: int64

# %% [markdown]
# ##### Conclusiones

# %% [markdown]
# Hay diferencias significativas entre cada empresa:
# - **Tandem Trade Marketing**: Tiene el mayor nombre de facturas (más de 10.000), la mayoría concentradas en Markeplace. Son de importe bajo y de alta frecuencia y se cobran inmediatamente, por tanto, tienen un riesgo de impago prácticamente nulo y pueden afectar negativamente al modelo de predicción aportando un sesgo positivo.
# - **Elogia Media**: facturación B2B con importes medio/altos

# %% [markdown]
# # MVP

# %% [markdown]
# Comenzaré realizando una versión mínima viable del modelo de predicción de impagos.
#
# Para facilitar el proceso, este modelo entrenará a partir de las facturas y podrá predecir si una factura va a ser pagada a tiempo o tarde.

# %%
# !pip install pydantic[email]

# %%
pip install mcp_odoo/.

# %%
pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in c:\users\ismae\miniconda3\lib\site-packages (1.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Connected to Odoo as albert.gil@yourtechtribe.com (uid: 430)
# Odoo server version: {'server_version': '16.0+e-20250313', 'server_version_info': [16, 0, 0, 'final', 0, 'e'], 'server_serie': '16.0', 'protocol_version': 1}

# %% [markdown]
# # Datos empresas

# %%
asyncio.run(data_retriever.get_all_companies())
# Out:
# [Company(id=1, name='Grupo Viko Digital Marketing, S.A.', currency_id=(1, 'EUR')),
#  Company(id=3, name='Elogia Media S.L.', currency_id=(1, 'EUR')),
#  Company(id=2, name='Ibrands Medios Interactivos SL', currency_id=(1, 'EUR')),
#  Company(id=5, name='Kraz Data Solutions SL', currency_id=(1, 'EUR')),
#  Company(id=6, name='Marketing4ecommerce Digital Content SL', currency_id=(1, 'EUR')),
#  Company(id=13, name='Octoplus Digital Shelf Optimization SL', currency_id=(1, 'EUR')),
#  Company(id=7, name='Tandem Trade Marketing SL', currency_id=(1, 'EUR')),
#  Company(id=11, name='DigitalPla2021, S.L.', currency_id=(1, 'EUR')),
#  Company(id=14, name='Ideas y Estrategia Digital SL', currency_id=(1, 'EUR')),
#  Company(id=8, name='INICIATIVAS VIRTUALES DE MEXICO', currency_id=(33, 'MXN')),
#  Company(id=12, name='IBRANDS MEDIOS INTERACTIVOS DE MEXICO', currency_id=(33, 'MXN')),
#  Company(id=9, name='MITTUM MARKETING RELACIONAL', currency_id=(33, 'MXN'))]

# %%
fields = [
        "id",
        "name",
        "email",
        "phone",
        "street",
        "city",
        "zip",
        "country_id",
        "customer_rank",
        "supplier_rank",
        "category_id",
        "company_type",
        "credit",
        "credit_limit",
        "debit",
        "debit_limit",
        "industry_id",
        "invoice_ids",
        "total_due",
        "total_invoiced",
        "total_overdue",
        "trust",
        "unpaid_invoice_ids",
        "unpaid_invoices_count",
    ]

partners = await odoo_connection.search_read(
        model="res.partner",
        domain=[("customer_rank", ">", 0)],
        fields=fields,
        limit=1000,
        offset=0
    )

# %%
payments = await odoo_connection.search_read(
        model="res.partner",
        domain=[("payment_type", "=", "inbound")],
        fields=[],
        limit=1000,
        offset=0
    )
# Out:
# ---------------------------------------------------------------------------
# Fault                                     Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\mcp_odoo\odoo\client.py:137, in OdooClient.execute_kw(self, model, method, args, kwargs)
#     136     models = xmlrpc.client.ServerProxy(self.object_endpoint)
# --> 137     return models.execute_kw(
#     138         self.database, self.uid, self.password,
#     139         model, method, args, kwargs
#     140     )
#     141 except Exception as e:
#     142     # If the error might be due to session expiry, try reconnecting once
#
# File ~\miniconda3\Lib\xmlrpc\client.py:1096, in _Method.__call__(self, *args)
#    1095 def __call__(self, *args):
# -> 1096     return self.__send(self.__name, args)
#
# File ~\miniconda3\Lib\xmlrpc\client.py:1435, in ServerProxy.__request(self, methodname, params)
#    1432 request = dumps(params, methodname, encoding=self.__encoding,
#    1433                 allow_none=self.__allow_none).encode(self.__encoding, 'xmlcharrefreplace')
# -> 1435 response = self.__transport.request(
#    1436     self.__host,
#    1437     self.__handler,
#    1438     request,
#    1439     verbose=self.__verbose
#    1440     )
#    1442 if len(response) == 1:
#
# File ~\miniconda3\Lib\xmlrpc\client.py:1140, in Transport.request(self, host, handler, request_body, verbose)
#    1139 try:
# -> 1140     return self.single_request(host, handler, request_body, verbose)
#    1141 except http.client.RemoteDisconnected:
#
# File ~\miniconda3\Lib\xmlrpc\client.py:1156, in Transport.single_request(self, host, handler, request_body, verbose)
#    1155         self.verbose = verbose
# -> 1156         return self.parse_response(resp)
#    1158 except Fault:
#
# File ~\miniconda3\Lib\xmlrpc\client.py:1325, in Transport.parse_response(self, response)
#    1323 p.close()
# -> 1325 return u.close()
#
# File ~\miniconda3\Lib\xmlrpc\client.py:642, in Unmarshaller.close(self)
#     641 if self._type == "fault":
# --> 642     raise Fault(**self._stack[0])
#     643 return tuple(self._stack)
#
# Fault: <Fault 1: 'Traceback (most recent call last):\n  File "/opt/odoo/odoo/odoo/addons/base/controllers/rpc.py", line 151, in xmlrpc_2\n    response = self._xmlrpc(service)\n               ^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/addons/base/controllers/rpc.py", line 127, in _xmlrpc\n    result = dispatch_rpc(service, method, params)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/http.py", line 369, in dispatch_rpc\n    return dispatch(method, params)\n           ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 56, in dispatch\n    res = execute_kw(db, uid, *params[3:])\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 79, in execute_kw\n    return execute(db, uid, obj, method, *args, **kw or {})\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 84, in execute\n    res = execute_cr(cr, uid, obj, method, *args, **kw)\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 70, in execute_cr\n    result = retrying(partial(odoo.api.call_kw, recs, method, args, kw), env)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 152, in retrying\n    result = func()\n             ^^^^^^\n  File "/opt/odoo/odoo/odoo/api.py", line 480, in call_kw\n    result = _call_kw_model(method, model, args, kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/api.py", line 451, in _call_kw_model\n    result = method(recs, *args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 5048, in search_read\n    records = self.search(domain or [], offset=offset, limit=limit, order=order)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 1533, in search\n    res = self._search(domain, offset=offset, limit=limit, order=order, count=count)\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/addons/base/models/res_partner.py", line 944, in _search\n    return super(Partner, self)._search(args, offset=offset, limit=limit, order=order,\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 4717, in _search\n    query = self._where_calc(domain)\n            ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 4482, in _where_calc\n    return expression.expression(domain, self).query\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/osv/expression.py", line 447, in __init__\n    self.parse()\n  File "/opt/odoo/odoo/odoo/osv/expression.py", line 674, in parse\n    raise ValueError("Invalid field %s.%s in leaf %s" % (model._name, path[0], str(leaf)))\nValueError: Invalid field res.partner.payment_type in leaf (\'payment_type\', \'=\', \'inbound\')\n'>
#
# During handling of the above exception, another exception occurred:
#
# OdooConnectionError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 payments = await odoo_connection.search_read(
#       2         model="res.partner",
#       3         domain=[("payment_type", "=", "inbound")],
#       4         fields=[],
#       5         limit=1000,
#       6         offset=0
#       7     )
#
# File ~\Documents\TFG\ai-agent-invoice-payment-prediction-b2b\src\data\odoo_connector.py:23, in OdooConnection.search_read(self, model, domain, fields, limit, offset)
#      22 async def search_read(self, model, domain, fields, limit=0, offset=0):
# ---> 23     return await self.client.search_read(model, domain, fields, limit, offset)
#
# File ~\miniconda3\Lib\site-packages\mcp_odoo\odoo\client.py:182, in OdooClient.search_read(self, model, domain, fields, limit, offset, order)
#     179 if order:
#     180     kwargs['order'] = order
# --> 182 return await self.execute_kw(model, 'search_read', [domain], kwargs)
#
# File ~\miniconda3\Lib\site-packages\mcp_odoo\odoo\client.py:150, in OdooClient.execute_kw(self, model, method, args, kwargs)
#     145     models = xmlrpc.client.ServerProxy(self.object_endpoint)
#     146     return models.execute_kw(
#     147         self.database, self.uid, self.password,
#     148         model, method, args, kwargs
#     149     )
# --> 150 raise OdooConnectionError(f"Error executing {method} on {model}: {str(e)}")
#
# OdooConnectionError: Error executing search_read on res.partner: <Fault 1: 'Traceback (most recent call last):\n  File "/opt/odoo/odoo/odoo/addons/base/controllers/rpc.py", line 151, in xmlrpc_2\n    response = self._xmlrpc(service)\n               ^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/addons/base/controllers/rpc.py", line 127, in _xmlrpc\n    result = dispatch_rpc(service, method, params)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/http.py", line 369, in dispatch_rpc\n    return dispatch(method, params)\n           ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 56, in dispatch\n    res = execute_kw(db, uid, *params[3:])\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 79, in execute_kw\n    return execute(db, uid, obj, method, *args, **kw or {})\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 84, in execute\n    res = execute_cr(cr, uid, obj, method, *args, **kw)\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 70, in execute_cr\n    result = retrying(partial(odoo.api.call_kw, recs, method, args, kw), env)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/service/model.py", line 152, in retrying\n    result = func()\n             ^^^^^^\n  File "/opt/odoo/odoo/odoo/api.py", line 480, in call_kw\n    result = _call_kw_model(method, model, args, kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/api.py", line 451, in _call_kw_model\n    result = method(recs, *args, **kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 5048, in search_read\n    records = self.search(domain or [], offset=offset, limit=limit, order=order)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 1533, in search\n    res = self._search(domain, offset=offset, limit=limit, order=order, count=count)\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/addons/base/models/res_partner.py", line 944, in _search\n    return super(Partner, self)._search(args, offset=offset, limit=limit, order=order,\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 4717, in _search\n    query = self._where_calc(domain)\n            ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/models.py", line 4482, in _where_calc\n    return expression.expression(domain, self).query\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/odoo/odoo/odoo/osv/expression.py", line 447, in __init__\n    self.parse()\n  File "/opt/odoo/odoo/odoo/osv/expression.py", line 674, in parse\n    raise ValueError("Invalid field %s.%s in leaf %s" % (model._name, path[0], str(leaf)))\nValueError: Invalid field res.partner.payment_type in leaf (\'payment_type\', \'=\', \'inbound\')\n'>

# %%
count_inbound = await odoo_connection.execute_kw(
    model="account.payment",
    method="search_count",
    args=[[("payment_type", "=", "outbound")]]
)

# %% [markdown]
# # Datos facturas

# %%
company_id = 14
invoices = asyncio.run(data_retriever.get_all_outbound_invoices(company_id))
invoices_df = pd.DataFrame([i.to_dict() for i in invoices])
# Out:
# Recuperadas 500 facturas, total: 500
# Recuperadas 95 facturas, total: 595

# %%
invoices_df.describe()
# Out:
#                   id  amount_total  amount_residual  days_overdue
# count     595.000000    595.000000       595.000000    595.000000
# mean   143420.842017   5338.248672       912.600571      7.858824
# std     21899.350306   8546.715734      4151.656529     13.038414
# min    121169.000000    108.730000         0.000000     -1.000000
# 25%    130328.500000    955.900000         0.000000      0.000000
# 50%    130477.000000   2178.000000         0.000000      4.000000
# 75%    157948.500000   6198.225000         0.000000     11.500000
# max    194734.000000  90096.600000     41964.870000    103.000000

# %%
invoices_df.columns.values
# Out:
# array(['id', 'name', 'move_type', 'payment_state', 'company_id',
#        'partner_id', 'currency_id', 'amount_total', 'amount_residual',
#        'invoice_date', 'invoice_date_due', 'journal_id', 'payment_dates',
#        'paid_late', 'days_overdue'], dtype=object)

# %%
invoices_df["payment_dates"].dtypes
# Out:
# dtype('O')

# %%
invoices_df["payment_state"].value_counts()
# Out:
# payment_state
# paid        515
# not_paid     80
# Name: count, dtype: int64

# %%
invoices_df["paid_late"].value_counts()
# Out:
# paid_late
# True     365
# False    150
# Name: count, dtype: int64

# %%
invoices_df["partner_id"].value_counts()
# Out:
# partner_id
# (13557, Chiesi España, S.A)                          124
# (13548, Esteve Pharmaceuticals SA)                   113
# (13558, Elanco Spain S.L.)                           106
# (8933, Zambon, S.A.U.)                                66
# (13559, Kern Pharma S.L.)                             47
# (13549, Swedish Orphan Biovitrum S.L.)                34
# (13542, Laboratorio Reig Jofre, S.A.)                 21
# (13547, Alexion Pharma Nordics AB)                    18
# (13543, Alexion Pharma GMBH)                          11
# (14595, Swedish Orphan Biovitrum AB (publ))            8
# (7583, Reckitt Benckiser Healthcare, S.A.)             8
# (14476, Faes Farma S.A.)                               7
# (13654, Atika Pharma S.L.)                             7
# (13545, Elanco AH Portugal Unipessoal Lda.)            6
# (13544, Angelini Pharma Portugal, Unipessoal Lda)      3
# (13553, AdSalutem Lullaai S.L)                         2
# (14627, Asociación Española Contra el Cáncer)          2
# (10, Elogia Media S.L.)                                2
# (14319, Neuraxpharm Spain s.l.u.)                      2
# (14921, Alexion Pharma Austria GmbH)                   1
# (14482, BRAEBURN WHISKY SPAIN, S.L.U)                  1
# (13889, Ophtalmic World Leaders)                       1
# (13939, Josep Soldevila Melgarejo)                     1
# (13684, Angelini Pharma España, S.L.U)                 1
# (13551, Swedish Orphan Biovitrum Unipessoal LDA)       1
# (13550, Laboratorios Vilardell S.A.)                   1
# (13552, Astellas Pharma S.A.)                          1
# Name: count, dtype: int64

# %%
invoices_df["currency_id"].value_counts()
# Out:
# currency_id
# (1, EUR)      12388
# (18, SEK)         9
# (142, GBP)        1
# Name: count, dtype: int64

# %%
invoices_df
# Out:
#           id             name    move_type payment_state  \
# 0     196743   FVE/2025/00376  out_invoice      not_paid
# 1     196654   FVE/2025/00375  out_invoice      not_paid
# 2     196649   FVE/2025/00374  out_invoice      not_paid
# 3     196631   FVE/2025/00373  out_invoice      not_paid
# 4     196628   FVE/2025/00372  out_invoice      not_paid
# ...      ...              ...          ...           ...
# 6343    9691  INV1/2022/00005  out_invoice          paid
# 6344    9690  INV1/2022/00004  out_invoice          paid
# 6345    9689  INV1/2022/00003  out_invoice          paid
# 6346    9688  INV1/2022/00002  out_invoice          paid
# 6347    9687  INV1/2022/00001  out_invoice          paid
#
#                   company_id  \
# 0     (3, Elogia Media S.L.)
# 1     (3, Elogia Media S.L.)
# 2     (3, Elogia Media S.L.)
# 3     (3, Elogia Media S.L.)
# 4     (3, Elogia Media S.L.)
# ...                      ...
# 6343  (3, Elogia Media S.L.)
# 6344  (3, Elogia Media S.L.)
# 6345  (3, Elogia Media S.L.)
# 6346  (3, Elogia Media S.L.)
# 6347  (3, Elogia Media S.L.)
#
#                                              partner_id currency_id  \
# 0             (8920, Boehringer Ingelheim España, S.A.)    (1, EUR)
# 1                  (14945, Olistic Research Labs, S.L.)    (1, EUR)
# 2                  (14945, Olistic Research Labs, S.L.)    (1, EUR)
# 3                  (14945, Olistic Research Labs, S.L.)    (1, EUR)
# 4                  (14945, Olistic Research Labs, S.L.)    (1, EUR)
# ...                                                 ...         ...
# 6343                         (9247, Apoteca Natura Spa)    (1, EUR)
# 6344                      (8301, Goiko Grill Group SL.)    (1, EUR)
# 6345  (7439, Boehringer Ingelheim Animal Health Espa...    (1, EUR)
# 6346                        (8663, Irmaos Vila Nova SA)    (1, EUR)
# 6347                             (8933, Zambon, S.A.U.)    (1, EUR)
#
#       amount_total  amount_residual invoice_date invoice_date_due  \
# 0           242.00           242.00   2025-06-17       2025-08-16
# 1           453.75           453.75   2025-06-12       2025-08-11
# 2           907.50           907.50   2025-06-12       2025-08-11
# 3          1210.00          1210.00   2025-06-11       2025-08-10
# 4          1210.00          1210.00   2025-06-11       2025-08-10
# ...            ...              ...          ...              ...
# 6343       2250.00             0.00   2022-12-31       2023-01-30
# 6344      11555.50             0.00   2022-12-31       2023-01-29
# 6345       1597.20             0.00   2022-12-31       2023-02-05
# 6346      12195.41             0.00   2022-12-31       2023-02-18
# 6347      17272.33             0.00   2022-12-31       2023-03-15
#
#                               journal_id payment_dates paid_late  days_overdue
# 0           (28, Facturas ventas Elogia)          None      None            -1
# 1           (28, Facturas ventas Elogia)          None      None            -1
# 2           (28, Facturas ventas Elogia)          None      None            -1
# 3           (28, Facturas ventas Elogia)          None      None            -1
# 4           (28, Facturas ventas Elogia)          None      None            -1
# ...                                  ...           ...       ...           ...
# 6343  (340, Carga facturas venta Elogia)    2023-02-01      True             2
# 6344  (340, Carga facturas venta Elogia)    2023-02-17      True            19
# 6345  (340, Carga facturas venta Elogia)    2023-03-01      True            24
# 6346  (340, Carga facturas venta Elogia)    2023-02-21      True             3
# 6347  (340, Carga facturas venta Elogia)    2023-03-17      True             2
#
# [6348 rows x 15 columns]
